# %% [markdown]
# # save qchronolyze analysis to md

# %%
from qChronolyze import *

# %%
import csv
with open('data/lemmata.tsv') as f:
    lemmata = [row for row in csv.DictReader(f, delimiter='\t') ]
    # lem = f.read()

print(lemmata[1]['Buckwalter'])
# print(lem)
# Out:
# {ll~ah

# %%
[lemma for lemma in lemmata if lemma["Lemma"] == "طاغوت"]
# Out:
# []

# %%
from aggregates import *

# %%
qL = [[{i: idols[i] for i in range(len(idols)) if idols[i][0]["strL"][0]["stri"] == "TaAguwt"}]]

# %%
qL = [
 [
    {
      "wrdDis": 82011,
      "strL": [
        { "stri": "wad~", "strTyp":"lem", "flt": "wadd",},
        { "stri": "wdd", "strTyp":"root", "flt": "",},
      ],
    },

    # {
    #   "wrdDis": 1,
    #   "strL": [
    #     # { "stri": "h", "strTyp": "stem", "poSp": "PRON", "flt": "H",},
    #     { "stri": "Alh", "flt": "(?:^((?!Allah).)*$)",},
    #     { "stri": "dwn", "flt": "(?:other|esides|exclud|Us|instead)",},
    #   ],
    # },
    # {
    #   "wrdDis": 1,
    #   "strL": [
    #     # { "stri": "h", "strTyp": "stem", "poSp": "PRON", "flt": "H",},
    #     { "stri": "raHma`n", "strTyp": "stem"},
    #     { "stri": "dwn", "flt": "(?:other|esides|exclud|Us|instead)",},
    #   ],
    # },
    # {
    #   "wrdDis": 1,
    #   "strL": [
    #     # { "stri": "h", "strTyp": "stem", "poSp": "PRON", "flt": "H",},
    #     { "stri": "rab~", "strTyp": "lem"},
    #     # { "stri": "dwn", "flt": "(?:other|esides|exclud|Us|instead)",},
    #   ],
    # },
  ],
]

# %%
jinn

# %%
from qChronolyze import querize

querize(
    
    ### uncomment whichever concept you want to display

    [
        # *qL,
        # [{'wrdDis': 0, 'strL': [{'stri': 'maAruwt', 'flt': 'marut'}]}],
        # {'TwE': '(?<!be )[Oo]bey'},
        # *angels,
        # *jinn
        # *spirituals,
        # *shirk,
        # *salah
        # *mamluk_yaman
        # *nisa
        # *ahl_kitab
        # *jhd
        # *ruh
        # *fadl
        # *zann,
        # shirk[79],
        # *foreign_vocabs
        *idols,
        
    ],
    
    ### uncomment chosen name for saved obsidian md file
     
    # 'zann',
    # 'spirituals',
    # 'firawn_taghut',
    # 'fadl',
    # 'ruh',
    # 'jhd_qtl',
    # 'ahl_kitab',
    # 'firawn_taghut',
    # 'nisa',
    # 'mamluk_yaman',
    # 'salah',
    # 'obedience',
    # 'shirk',
    # 'iman_islam',
    # "anbiya",
    # "foreign_vocab",
    # "animals",

    ### uncomment chosen tafsir reference language for linking
    # 'Arabic',
    refLng = 'arabic',
    # 'Bengali',
    # /
    # '1',

    ### uncomment chosen presentation style
    # pres='table',
    pres='table',

    )
# Out:
# <style type="text/css">
# #T_9354e_row0_col0, #T_9354e_row0_col1, #T_9354e_row0_col2, #T_9354e_row0_col3, #T_9354e_row0_col4, #T_9354e_row0_col5, #T_9354e_row0_col6, #T_9354e_row8_col0, #T_9354e_row8_col1, #T_9354e_row8_col2, #T_9354e_row8_col3, #T_9354e_row8_col4, #T_9354e_row8_col5, #T_9354e_row8_col6 {
#   background-color: rgb(100,220,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row1_col0, #T_9354e_row1_col1, #T_9354e_row1_col2, #T_9354e_row1_col3, #T_9354e_row1_col4, #T_9354e_row1_col5, #T_9354e_row1_col6, #T_9354e_row30_col0, #T_9354e_row30_col1, #T_9354e_row30_col2, #T_9354e_row30_col3, #T_9354e_row30_col4, #T_9354e_row30_col5, #T_9354e_row30_col6 {
#   background-color: rgb(110,209,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row2_col0, #T_9354e_row2_col1, #T_9354e_row2_col2, #T_9354e_row2_col3, #T_9354e_row2_col4, #T_9354e_row2_col5, #T_9354e_row2_col6, #T_9354e_row35_col0, #T_9354e_row35_col1, #T_9354e_row35_col2, #T_9354e_row35_col3, #T_9354e_row35_col4, #T_9354e_row35_col5, #T_9354e_row35_col6 {
#   background-color: rgb(121,198,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row3_col0, #T_9354e_row3_col1, #T_9354e_row3_col2, #T_9354e_row3_col3, #T_9354e_row3_col4, #T_9354e_row3_col5, #T_9354e_row3_col6, #T_9354e_row7_col0, #T_9354e_row7_col1, #T_9354e_row7_col2, #T_9354e_row7_col3, #T_9354e_row7_col4, #T_9354e_row7_col5, #T_9354e_row7_col6 {
#   background-color: rgb(132,187,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row4_col0, #T_9354e_row4_col1, #T_9354e_row4_col2, #T_9354e_row4_col3, #T_9354e_row4_col4, #T_9354e_row4_col5, #T_9354e_row4_col6, #T_9354e_row27_col0, #T_9354e_row27_col1, #T_9354e_row27_col2, #T_9354e_row27_col3, #T_9354e_row27_col4, #T_9354e_row27_col5, #T_9354e_row27_col6 {
#   background-color: rgb(142,177,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row5_col0, #T_9354e_row5_col1, #T_9354e_row5_col2, #T_9354e_row5_col3, #T_9354e_row5_col4, #T_9354e_row5_col5, #T_9354e_row5_col6, #T_9354e_row6_col0, #T_9354e_row6_col1, #T_9354e_row6_col2, #T_9354e_row6_col3, #T_9354e_row6_col4, #T_9354e_row6_col5, #T_9354e_row6_col6 {
#   background-color: rgb(153,166,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row9_col0, #T_9354e_row9_col1, #T_9354e_row9_col2, #T_9354e_row9_col3, #T_9354e_row9_col4, #T_9354e_row9_col5, #T_9354e_row9_col6, #T_9354e_row11_col0, #T_9354e_row11_col1, #T_9354e_row11_col2, #T_9354e_row11_col3, #T_9354e_row11_col4, #T_9354e_row11_col5, #T_9354e_row11_col6 {
#   background-color: rgb(164,155,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row10_col0, #T_9354e_row10_col1, #T_9354e_row10_col2, #T_9354e_row10_col3, #T_9354e_row10_col4, #T_9354e_row10_col5, #T_9354e_row10_col6, #T_9354e_row12_col0, #T_9354e_row12_col1, #T_9354e_row12_col2, #T_9354e_row12_col3, #T_9354e_row12_col4, #T_9354e_row12_col5, #T_9354e_row12_col6, #T_9354e_row17_col0, #T_9354e_row17_col1, #T_9354e_row17_col2, #T_9354e_row17_col3, #T_9354e_row17_col4, #T_9354e_row17_col5, #T_9354e_row17_col6, #T_9354e_row18_col0, #T_9354e_row18_col1, #T_9354e_row18_col2, #T_9354e_row18_col3, #T_9354e_row18_col4, #T_9354e_row18_col5, #T_9354e_row18_col6, #T_9354e_row28_col0, #T_9354e_row28_col1, #T_9354e_row28_col2, #T_9354e_row28_col3, #T_9354e_row28_col4, #T_9354e_row28_col5, #T_9354e_row28_col6, #T_9354e_row29_col0, #T_9354e_row29_col1, #T_9354e_row29_col2, #T_9354e_row29_col3, #T_9354e_row29_col4, #T_9354e_row29_col5, #T_9354e_row29_col6, #T_9354e_row32_col0, #T_9354e_row32_col1, #T_9354e_row32_col2, #T_9354e_row32_col3, #T_9354e_row32_col4, #T_9354e_row32_col5, #T_9354e_row32_col6, #T_9354e_row33_col0, #T_9354e_row33_col1, #T_9354e_row33_col2, #T_9354e_row33_col3, #T_9354e_row33_col4, #T_9354e_row33_col5, #T_9354e_row33_col6, #T_9354e_row34_col0, #T_9354e_row34_col1, #T_9354e_row34_col2, #T_9354e_row34_col3, #T_9354e_row34_col4, #T_9354e_row34_col5, #T_9354e_row34_col6, #T_9354e_row36_col0, #T_9354e_row36_col1, #T_9354e_row36_col2, #T_9354e_row36_col3, #T_9354e_row36_col4, #T_9354e_row36_col5, #T_9354e_row36_col6, #T_9354e_row37_col0, #T_9354e_row37_col1, #T_9354e_row37_col2, #T_9354e_row37_col3, #T_9354e_row37_col4, #T_9354e_row37_col5, #T_9354e_row37_col6 {
#   background-color: rgb(175,145,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row13_col0, #T_9354e_row13_col1, #T_9354e_row13_col2, #T_9354e_row13_col3, #T_9354e_row13_col4, #T_9354e_row13_col5, #T_9354e_row13_col6, #T_9354e_row22_col0, #T_9354e_row22_col1, #T_9354e_row22_col2, #T_9354e_row22_col3, #T_9354e_row22_col4, #T_9354e_row22_col5, #T_9354e_row22_col6 {
#   background-color: rgb(185,134,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row14_col0, #T_9354e_row14_col1, #T_9354e_row14_col2, #T_9354e_row14_col3, #T_9354e_row14_col4, #T_9354e_row14_col5, #T_9354e_row14_col6, #T_9354e_row15_col0, #T_9354e_row15_col1, #T_9354e_row15_col2, #T_9354e_row15_col3, #T_9354e_row15_col4, #T_9354e_row15_col5, #T_9354e_row15_col6 {
#   background-color: rgb(196,123,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row16_col0, #T_9354e_row16_col1, #T_9354e_row16_col2, #T_9354e_row16_col3, #T_9354e_row16_col4, #T_9354e_row16_col5, #T_9354e_row16_col6, #T_9354e_row23_col0, #T_9354e_row23_col1, #T_9354e_row23_col2, #T_9354e_row23_col3, #T_9354e_row23_col4, #T_9354e_row23_col5, #T_9354e_row23_col6 {
#   background-color: rgb(207,112,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row19_col0, #T_9354e_row19_col1, #T_9354e_row19_col2, #T_9354e_row19_col3, #T_9354e_row19_col4, #T_9354e_row19_col5, #T_9354e_row19_col6, #T_9354e_row21_col0, #T_9354e_row21_col1, #T_9354e_row21_col2, #T_9354e_row21_col3, #T_9354e_row21_col4, #T_9354e_row21_col5, #T_9354e_row21_col6 {
#   background-color: rgb(217,102,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row20_col0, #T_9354e_row20_col1, #T_9354e_row20_col2, #T_9354e_row20_col3, #T_9354e_row20_col4, #T_9354e_row20_col5, #T_9354e_row20_col6, #T_9354e_row26_col0, #T_9354e_row26_col1, #T_9354e_row26_col2, #T_9354e_row26_col3, #T_9354e_row26_col4, #T_9354e_row26_col5, #T_9354e_row26_col6 {
#   background-color: rgb(228,91,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row24_col0, #T_9354e_row24_col1, #T_9354e_row24_col2, #T_9354e_row24_col3, #T_9354e_row24_col4, #T_9354e_row24_col5, #T_9354e_row24_col6, #T_9354e_row31_col0, #T_9354e_row31_col1, #T_9354e_row31_col2, #T_9354e_row31_col3, #T_9354e_row31_col4, #T_9354e_row31_col5, #T_9354e_row31_col6 {
#   background-color: rgb(239,80,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_9354e_row25_col0, #T_9354e_row25_col1, #T_9354e_row25_col2, #T_9354e_row25_col3, #T_9354e_row25_col4, #T_9354e_row25_col5, #T_9354e_row25_col6 {
#   background-color: rgb(250,70,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# </style>
# <table id="T_9354e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9354e_level0_col0" class="col_heading level0 col0" >verses_before</th>
#       <th id="T_9354e_level0_col1" class="col_heading level0 col1" >surah_ayah</th>
#       <th id="T_9354e_level0_col2" class="col_heading level0 col2" >position</th>
#       <th id="T_9354e_level0_col3" class="col_heading level0 col3" >string</th>
#       <th id="T_9354e_level0_col4" class="col_heading level0 col4" >meaning</th>
#       <th id="T_9354e_level0_col5" class="col_heading level0 col5" >ayah_link</th>
#       <th id="T_9354e_level0_col6" class="col_heading level0 col6" >query</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9354e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9354e_row0_col0" class="data row0 col0" >326</td>
#       <td id="T_9354e_row0_col1" class="data row0 col1" >53:19</td>
#       <td id="T_9354e_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_9354e_row0

# %%
from qChronoMd import qChronoMd

qChronoMd(
    jinn
### enter pair of word/root and meaning filtering regex as key-value pair dictionary
# {
#    '$Tn':  # english word / transliterated root https://corpus.quran.com/java/buckwalter.jsp
#     '',   # regex filter for meaning
#     'jnn':
#     'jinn'
# },

### tafsir reference language
# 'Arabic',
# /
# '1',

### presentation style
# pres='plot',
    ,
    "jinn"
    # "makan"
    ,
    "arabic"

)
# Out:
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ap flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ap flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jaA^n~ flt: (?:[Ss]nake|[Rr]eptile|[Vv]iper) strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jaA^n~ flt: (?:[Ss]nake|[Rr]eptile|[Vv]iper) strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jaA^n~ flt: ^((?![Ss]nake|[Rr]eptile|[Vv]iper).)*$ strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jaA^n~ flt: ^((?![Ss]nake|[Rr]eptile|[Vv]iper).)*$ strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  khn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  khn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  malak flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  malak flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Eiforiyt flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Eiforiyt flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  qariyn flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  qariyn flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  *rr flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  *rr flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  <iboliys flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  <iboliys flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  <iboliys flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  <iboliys flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  $Tn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Tn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  majonuwn flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  majonuwn flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt:  strTyp: root frm: None poSp: V inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt:  strTyp: root frm: All poSp: V inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt: (?:[Pp]aradise|[Gg]arden|[Hh]eaven) strTyp: root frm: None poSp: N inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt: (?:[Pp]aradise|[Gg]arden|[Hh]eaven) strTyp: root frm: All poSp: N inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt: ^((?![Pp]aradise|[Gg]arden|[Hh]eaven|[Mm]ad|[Cc]raz|[Dd]emon|[Dd]evil|[Jj]inn).)*$ strTyp: root frm: None poSp: N inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt: ^((?![Pp]aradise|[Gg]arden|[Hh]eaven|[Mm]ad|[Cc]raz|[Dd]emon|[Dd]evil|[Jj]inn).)*$ strTyp: root frm: All poSp: N inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Ew* flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ew* flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  wly flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wly flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  $rk flt:  strTyp: root frm: None poSp: N inpLng: None inpSch: None
# props set in str init:  stri:  $rk flt:  strTyp: root frm: All poSp: N inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ebd flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ebd flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ap flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ap flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  nsb flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nsb flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# [<qChronolyze.combClass object at 0x7f50ea62a130>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a130>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# [<qChronolyze.combClass object at 0x7f50ea62a160>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a160>
# optStInsts after comb: []
# for string: jin~ap
# file found for jin~ap
# Successfully loaded data from 'data/cache/arb/جِنَّة/lem/All/All.tsv: lenght 10'
# [<qChronolyze.combClass object at 0x7f50ea62a2b0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a2b0>
# optStInsts after comb: []
# for string: jaA^n~
# file found for jaA^n~
# Successfully loaded data from 'data/cache/arb/جَآنّ/lem/All/All.tsv: lenght 7'
# [<qChronolyze.combClass object at 0x7f50ea62a400>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a400>
# optStInsts after comb: []
# for string: jaA^n~
# file found for jaA^n~
# Successfully loaded data from 'data/cache/arb/جَآنّ/lem/All/All.tsv: lenght 7'
# [<qChronolyze.combClass object at 0x7f50ea62a370>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a370>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/All/All/All.tsv: lenght 201'
# for string: khn
# file found for khn
# Successfully loaded data from 'data/cache/arb/كهن/All/All/All.tsv: lenght 2'
# [<qChronolyze.combClass object at 0x7f50ea62a490>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a490>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: malak
# file found for malak
# Successfully loaded data from 'data/cache/arb/مَلَك/lem/All/All.tsv: lenght 88'
# [<qChronolyze.combClass object at 0x7f50ea62a4c0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a4c0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: Eiforiyt
# file found for Eiforiyt
# Successfully loaded data from 'data/cache/arb/عِفْرِيت/lem/All/All.tsv: lenght 1'
# [<qChronolyze.combClass object at 0x7f50ea62a460>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a460>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: qariyn
# file found for qariyn
# Successfully loaded data from 'data/cache/arb/قَرِين/lem/All/All.tsv: lenght 8'
# [<qChronolyze.combClass object at 0x7f50ea62a2e0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a2e0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: *rr
# file found for *rr
# Successfully loaded data from 'data/cache/arb/ذرر/root/All/All.tsv: lenght 38'
# for string: <iboliys
# file found for <iboliys
# Successfully loaded data from 'data/cache/arb/إِبْلِيس/lem/All/All.tsv: lenght 11'
# [<qChronolyze.combClass object at 0x7f50ea62a670>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a670>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: <iboliys
# file found for <iboliys
# Successfully loaded data from 'data/cache/arb/إِبْلِيس/lem/All/All.tsv: lenght 11'
# [<qChronolyze.combClass object at 0x7f50ea62a850>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a850>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: $Tn
# file found for $Tn
# Successfully loaded data from 'data/cache/arb/شطن/All/All/All.tsv: lenght 88'
# [<qChronolyze.combClass object at 0x7f50ea62a790>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a790>
# optStInsts after comb: []
# for string: majonuwn
# file found for majonuwn
# Successfully loaded data from 'data/cache/arb/مَجْنُون/lem/All/All.tsv: lenght 11'
# [<qChronolyze.combClass object at 0x7f50ea62a6a0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a6a0>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/root/All/V.tsv: lenght 1'
# [<qChronolyze.combClass object at 0x7f50ea62a9d0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62a9d0>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/root/All/N.tsv: lenght 149'
# [<qChronolyze.combClass object at 0x7f50ea62aa60>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62aa60>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/root/All/N.tsv: lenght 149'
# [<qChronolyze.combClass object at 0x7f50ea62aaf0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62aaf0>
# optStInsts after comb: []
# for string: Ew*
# file found for Ew*
# Successfully loaded data from 'data/cache/arb/عوذ/All/All/All.tsv: lenght 17'
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# [<qChronolyze.combClass object at 0x7f50ea62ab80>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62ab80>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: wly
# file found for wly
# Successfully loaded data from 'data/cache/arb/ولي/All/All/All.tsv: lenght 232'
# [<qChronolyze.combClass object at 0x7f50ea62abe0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62abe0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: $rk
# file found for $rk
# Successfully loaded data from 'data/cache/arb/شرك/root/All/N.tsv: lenght 96'
# [<qChronolyze.combClass object at 0x7f50ea62ac40>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62ac40>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: Ebd
# file found for Ebd
# Successfully loaded data from 'data/cache/arb/عبد/All/All/All.tsv: lenght 275'
# [<qChronolyze.combClass object at 0x7f50ea62ad00>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f50ea62ad00>
# optStInsts after comb: []
# for string: jin~ap
# file found for jin~ap
# Successfully loaded data from 'data/cache/arb/جِنَّة/lem/All/All.tsv: lenght 10'
# for string: nsb
# file found for nsb
# Successfully loaded data from 'data/cache/arb/نسب/All/All/All.tsv: lenght 3'
#
# total 175 instances found
# 'sorter.json' found'
# last item in sorter: 110:3
# successfully loaded sorter of length 6236 from 'sorter.json'
# new not in old 1: 6:129
# new not in old 2: 51:54
# new not in old 3: 18:52
# for 81:13 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 1: 81:13
# for 50:31 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 2: 50:31
# for 7:19 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 3: 7:19
# for 7:22 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 4: 7:22
# for 7:27 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 5: 7:27
# for 7:40 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 6: 7:40
# for 7:42 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 7: 7:42
# for 7:43 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 8: 7:43
# for 7:44 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 9: 7:44
# for 7:46 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 10: 7:46
# for 7:49 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 11: 7:49
# for 7:50 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 12: 7:50
# for 36:26 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 13: 36:26
# for 36:55 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 14: 36:55
# for 25:24 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 15: 25:24
# for 19:60 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 16: 19:60
# for 19:63 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 17: 19:63
# for 20:117 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 18: 20:117
# for 20:121 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 19: 20:121
# for 26:90 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 20: 26:90
# for 10:26 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 21: 10:26
# for 11:23 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 22: 11:23
# for 11:108 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 23: 11:108
# for 39:73 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 24: 39:73
# for 39:74 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 25: 39:74
# for 40:40 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 26: 40:40
# for 42:7 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 27: 42:7
# for 43:70 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 28: 43:70
# for 43:72 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 29: 43:72
# for 46:14 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 30: 46:14
# for 46:16 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 31: 46:16
# for 16:32 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 32: 16:32
# for 79:41 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 33: 79:41
# for 29:58 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 34: 29:58
# for 2:35 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 35: 2:35
# for 2:82 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 36: 2:82
# for 2:111 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 37: 2:111
# for 2:214 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 38: 2:214
# for 2:221 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 39: 2:221
# for 3:142 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 40: 3:142
# for 3:185 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 41: 3:185
# for 4:124 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 42: 4:124
# for 47:6 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 43: 47:6
# for 47:15 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 44: 47:15
# for 13:35 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 45: 13:35
# for 59:20 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 46: 59:20
# for 66:11 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 47: 66:11
# for 5:72 secondaries:  [('## >>> جنن ()\n', '', '\n\n[[#68:2]]\n[[#68:2]]')]
#
# old not in new 48: 5:72
# for 9:111 secondaries:  [('## >>> جنن ()\n', '', '[[#68:2]]\n[[#68:2]]')]
#
# old not in new 49: 9:111
#
# Number of ayahs: 201
#
# query left at 68:2 : مَجْنُون ()
#
# query left at 68:2 : جنن ()
#
# query left at 68:34 : جنن ((?:[Pp]aradise|[Gg]arden|[Hh]eaven))
#
# query left at 68:34 : >>> جنن ()
#
# query left at 68:51 : >>> مَجْنُون ()
#
# query left at 74:40 : >>> جنن ((?:[Pp]aradise|[Gg]arden|[Hh]eaven))
#
# query left at 114:6 : جِنَّة ()
#
# query left at 7:38 : جِنّ ()
#
# query left at 7:179 : >>> جِنّ ()
#
# query left at 7:184 : >>> جِنَّة ()
#
# query left at 72:6 : عوذ جِنّ ( )
#
# query left at 27:10 : جَآنّ ((?:[Ss]nake|[Rr]eptile|[Vv]iper))
#
# query left at 27:10 : جنن (^((?![Pp]aradise|[Gg]arden|[Hh]eaven|[Mm]ad|[Cc]raz|[Dd]emon|[Dd]evil|[Jj]inn).)*$)
#
# query left at 27:10 : جَآنّ ()
#
# query left at 27:39 : جِنّ عِفْرِيت ( )
#
# query left at 28:31 : >>> جَآنّ ((?:[Ss]nake|[Rr]eptile|[Vv]iper))
#
# query left at 28:31 : >>> جنن (^((?![Pp]aradise|[Gg]arden|[Hh]eaven|[Mm]ad|[Cc]raz|[Dd]emon|[Dd]evil|[Jj]inn).)*$)
#
# query left at 28:31 : >>> جَآنّ ()
#
# query left at 15:27 : جَآنّ (^((?![Ss]nake|[Rr]eptile|[Vv]iper).)*$)
#
# query left at 6:100 : جِنّ شرك ( )
#
# query left at 6:111 : جِنّ مَلَك ( )
#
# query left at 6:112 : جِنّ شطن ( )
#
# query left at 6:112 : >>> جِنّ مَلَك ( )
#
# query left at 6:128 : جِنّ ولي ( )
#
# query left at 37:158 : جِنَّة نسب ( )
#
# query left at 34:41 : جِنّ عبد ( )
#
# query left at 41:25 : جِنّ قَرِين ( )
#
# query left at 18:50 : جِنّ ذرر إِبْلِيس (  )
#
# query left at 18:50 : جِنّ إِبْلِيس ( )
#
# query left at 52:29 : جنن كهن ( )
#
# query left at 55:15 : >>> جَآنّ (^((?![Ss]nake|[Rr]eptile|[Vv]iper).)*$)

# %%
from qChronoMd import qChronoMd

qChronoMd(
    
    ### uncomment whichever concept you want to save

    [
        # {'TwE': '(?<!be )[Oo]bey'},
        # *spirituals,
        # *shirk2,
        *jinn,
        # *salah
        # *mamluk_yaman
        # *nisa
        # *ahl_kitab
        # *jhd
        # *ruh
        # *fadl
        # *zann,
        # *animals,
        # *foreign_vocabs
        
    ],
    
    ### uncomment chosen filename for saving in markdown format for obsidian
     
    # 'zann',
    # 'spirituals',
    # 'firawn_taghut',
    # 'fadl',
    # 'ruh',
    # 'jhd_qtl',
    # 'ahl_kitab',
    # 'firawn_taghut',
    # 'nisa',
    # 'mamluk_yaman',
    # 'salah2',
    # 'obedience',
    # 'shirk4',
    "jinn",
    # 'iman_islam',
    # "anbiya",
    # "foreign_vocab",
    # "animals",

    ### uncomment chosen tafsir reference for linking in file
    # "ar-tafsir-al-tabari",
    # "bn-tafseer-ibn-e-kaseer",
    "arabic",

)
# Out:
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ap flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ap flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jaA^n~ flt: (?:[Ss]nake|[Rr]eptile|[Vv]iper) strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jaA^n~ flt: (?:[Ss]nake|[Rr]eptile|[Vv]iper) strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jaA^n~ flt: ^((?![Ss]nake|[Rr]eptile|[Vv]iper).)*$ strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jaA^n~ flt: ^((?![Ss]nake|[Rr]eptile|[Vv]iper).)*$ strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  khn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  khn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  malak flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  malak flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Eiforiyt flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Eiforiyt flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  qariyn flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  qariyn flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  *rr flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  *rr flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  <iboliys flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  <iboliys flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  <iboliys flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  <iboliys flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  $Tn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Tn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  majonuwn flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  majonuwn flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt:  strTyp: root frm: None poSp: V inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt:  strTyp: root frm: All poSp: V inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt: (?:[Pp]aradise|[Gg]arden|[Hh]eaven) strTyp: root frm: None poSp: N inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt: (?:[Pp]aradise|[Gg]arden|[Hh]eaven) strTyp: root frm: All poSp: N inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt: ^((?![Pp]aradise|[Gg]arden|[Hh]eaven|[Mm]ad|[Cc]raz|[Dd]emon|[Dd]evil|[Jj]inn).)*$ strTyp: root frm: None poSp: N inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt: ^((?![Pp]aradise|[Gg]arden|[Hh]eaven|[Mm]ad|[Cc]raz|[Dd]emon|[Dd]evil|[Jj]inn).)*$ strTyp: root frm: All poSp: N inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Ew* flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ew* flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  wly flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wly flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  $rk flt:  strTyp: root frm: None poSp: N inpLng: None inpSch: None
# props set in str init:  stri:  $rk flt:  strTyp: root frm: All poSp: N inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ebd flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ebd flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ap flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ap flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  nsb flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nsb flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# [<qChronolyze.combClass object at 0x7f9f9c5267c0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c5267c0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# [<qChronolyze.combClass object at 0x7f9f9c5267f0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c5267f0>
# optStInsts after comb: []
# for string: jin~ap
# file found for jin~ap
# Successfully loaded data from 'data/cache/arb/جِنَّة/lem/All/All.tsv: lenght 10'
# [<qChronolyze.combClass object at 0x7f9f9c5268b0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c5268b0>
# optStInsts after comb: []
# for string: jaA^n~
# file found for jaA^n~
# Successfully loaded data from 'data/cache/arb/جَآنّ/lem/All/All.tsv: lenght 7'
# [<qChronolyze.combClass object at 0x7f9f9c526910>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526910>
# optStInsts after comb: []
# for string: jaA^n~
# file found for jaA^n~
# Successfully loaded data from 'data/cache/arb/جَآنّ/lem/All/All.tsv: lenght 7'
# [<qChronolyze.combClass object at 0x7f9f9c5269d0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c5269d0>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/All/All/All.tsv: lenght 201'
# for string: khn
# file found for khn
# Successfully loaded data from 'data/cache/arb/كهن/All/All/All.tsv: lenght 2'
# [<qChronolyze.combClass object at 0x7f9f9c526a60>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526a60>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: malak
# file found for malak
# Successfully loaded data from 'data/cache/arb/مَلَك/lem/All/All.tsv: lenght 88'
# [<qChronolyze.combClass object at 0x7f9f9c526ac0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526ac0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: Eiforiyt
# file found for Eiforiyt
# Successfully loaded data from 'data/cache/arb/عِفْرِيت/lem/All/All.tsv: lenght 1'
# [<qChronolyze.combClass object at 0x7f9f9c526b20>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526b20>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: qariyn
# file found for qariyn
# Successfully loaded data from 'data/cache/arb/قَرِين/lem/All/All.tsv: lenght 8'
# [<qChronolyze.combClass object at 0x7f9f9c526be0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526be0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: *rr
# file found for *rr
# Successfully loaded data from 'data/cache/arb/ذرر/root/All/All.tsv: lenght 38'
# for string: <iboliys
# file found for <iboliys
# Successfully loaded data from 'data/cache/arb/إِبْلِيس/lem/All/All.tsv: lenght 11'
# [<qChronolyze.combClass object at 0x7f9f9c526ca0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526ca0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: <iboliys
# file found for <iboliys
# Successfully loaded data from 'data/cache/arb/إِبْلِيس/lem/All/All.tsv: lenght 11'
# [<qChronolyze.combClass object at 0x7f9f9c526d60>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526d60>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: $Tn
# file found for $Tn
# Successfully loaded data from 'data/cache/arb/شطن/All/All/All.tsv: lenght 88'
# [<qChronolyze.combClass object at 0x7f9f9c526e20>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526e20>
# optStInsts after comb: []
# for string: majonuwn
# file found for majonuwn
# Successfully loaded data from 'data/cache/arb/مَجْنُون/lem/All/All.tsv: lenght 11'
# [<qChronolyze.combClass object at 0x7f9f9c526f10>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526f10>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/root/All/V.tsv: lenght 1'
# [<qChronolyze.combClass object at 0x7f9f9c526490>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526490>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/root/All/N.tsv: lenght 149'
# [<qChronolyze.combClass object at 0x7f9f9c526400>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526400>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/root/All/N.tsv: lenght 149'
# [<qChronolyze.combClass object at 0x7f9f9c526310>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526310>
# optStInsts after comb: []
# for string: Ew*
# file found for Ew*
# Successfully loaded data from 'data/cache/arb/عوذ/All/All/All.tsv: lenght 17'
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# [<qChronolyze.combClass object at 0x7f9f9c526280>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526280>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: wly
# file found for wly
# Successfully loaded data from 'data/cache/arb/ولي/All/All/All.tsv: lenght 232'
# [<qChronolyze.combClass object at 0x7f9f9c526220>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526220>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: $rk
# file found for $rk
# Successfully loaded data from 'data/cache/arb/شرك/root/All/N.tsv: lenght 96'
# [<qChronolyze.combClass object at 0x7f9f9c526190>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c526190>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.tsv: lenght 22'
# for string: Ebd
# file found for Ebd
# Successfully loaded data from 'data/cache/arb/عبد/All/All/All.tsv: lenght 275'
# [<qChronolyze.combClass object at 0x7f9f9c5260a0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f9f9c5260a0>
# optStInsts after comb: []
# for string: jin~ap
# file found for jin~ap
# Successfully loaded data from 'data/cache/arb/جِنَّة/lem/All/All.tsv: lenght 10'
# for string: nsb
# file found for nsb
# Successfully loaded data from 'data/cache/arb/نسب/All/All/All.tsv: lenght 3'
#
# total 175 instances found
# 'sorter.json' found'
# last item in sorter: 110:3
# successfully loaded sorter of length 6236 from 'sorter.json'
# new not in old 1: 68:2
# new not in old 2: 68:34
# new not in old 3: 68:51
# new not in old 4: 74:40
# new not in old 5: 81:22
# new not in old 6: 89:30
# new not in old 7: 114:6
# new not in old 8: 53:15
# new not in old 9: 85:11
# new not in old 10: 50:9
# new not in old 11: 54:9
# new not in old 12: 54:54
# new not in old 13: 38:50
# new not in old 14: 7:38
# new not in old 15: 7:179
# new not in old 16: 7:184
# new not in old 17: 72:1
# new not in old 18: 72:5
# new not in old 19: 72:6
# new not in old 20: 36:34
# new not in old 21: 25:8
# new not in old 22: 25:10
# new not in old 23: 25:15
# new not in old 24: 35:33
# new not in old 25: 19:61
# new not in old 26: 20:76
# new not in old 27: 56:12
# new not in old 28: 56:89
# new not in old 29: 26:27
# new not in old 30: 26:57
# new not in old 31: 26:85
# new not in old 32: 26:134
# new not in old 33: 26:147
# new not in old 34: 27:10
# new not in old 35: 27:17
# new not in old 36: 27:39
# new not in old 37: 28:31
# new not in old 38: 17:88
# new not in old 39: 17:91
# new not in old 40: 10:9
# new not in old 41: 11:119
# new not in old 42: 15:6
# new not in old 43: 15:27
# new not in old 44: 15:45
# new not in old 45: 6:76
# new not in old 46: 6:99
# new not in old 47: 6:100
# new not in old 48: 6:111
# new not in old 49: 6:112
# new not in old 50: 6:128
# new not in old 51: 6:129
# new not in old 52: 6:130
# new not in old 53: 6:141
# new not in old 54: 37:36
# new not in old 55: 37:43
# new not in old 56: 37:158
# new not in old 57: 31:8
# new not in old 58: 34:8
# new not in old 59: 34:12
# new not in old 60: 34:14
# new not in old 61: 34:15
# new not in old 62: 34:16
# new not in old 63: 34:40
# new not in old 64: 34:41
# new not in old 65: 34:46
# new not in old 66: 40:8
# new not in old 67: 41:25
# new not in old 68: 41:29
# new not in old 69: 41:30
# new not in old 70: 42:22
# new not in old 71: 44:14
# new not in old 72: 44:25
# new not in old 73: 44:52
# new not in old 74: 46:18
# new not in old 75: 46:29
# new not in old 76: 51:15
# new not in old 77: 51:39
# new not in old 78: 51:52
# new not in old 79: 51:54
# new not in old 80: 51:56
# new not in old 81: 88:10
# new not in old 82: 18:31
# new not in old 83: 18:32
# new not in old 84: 18:33
# new not in old 85: 18:35
# new not in old 86: 18:39
# new not in old 87: 18:40
# new not in old 88: 18:50
# new not in old 89: 18:52
# new not in old 90: 18:107
# new not in old 91: 16:31
# new not in old 92: 71:12
# new not in old 93: 14:23
# new not in old 94: 23:19
# new not in old 95: 23:25
# new not in old 96: 23:70
# new not in old 97: 32:13
# new not in old 98: 52:17
# new not in old 99: 52:29
# new not in old 100: 69:22
# new not in old 101: 70:35
# new not in old 102: 70:38
# new not in old 103: 78:16
# new not in old 104: 68:17
# new not in old 105: 53:32
# new not in old 106: 32:19
# new not in old 107: 2:25
# new not in old 108: 2:265
# new not in old 109: 2:266
# new not in old 110: 3:15
# new not in old 111: 3:133
# new not in old 112: 3:136
# new not in old 113: 3:195
# new not in old 114: 3:198
# new not in old 115: 4:13
# new not in old 116: 4:57
# new not in old 117: 4:122
# new not in old 118: 57:12
# new not in old 119: 57:21
# new not in old 120: 47:12
# new not in old 121: 13:4
# new not in old 122: 13:23
# new not in old 123: 55:15
# new not in old 124: 55:33
# new not in old 125: 55:39
# new not in old 126: 55:46
# new not in old 127: 55:54
# new not in old 128: 55:56
# new not in old 129: 55:62
# new not in old 130: 55:74
# new not in old 131: 76:12
# new not in old 132: 65:11
# new not in old 133: 98:8
# new not in old 134: 22:14
# new not in old 135: 22:23
# new not in old 136: 22:56
# new not in old 137: 63:2
# new not in old 138: 58:16
# new not in old 139: 58:22
# new not in old 140: 66:8
# new not in old 141: 64:9
# new not in old 142: 61:12
# new not in old 143: 48:5
# new not in old 144: 48:17
# new not in old 145: 5:12
# new not in old 146: 5:65
# new not in old 147: 5:85
# new not in old 148: 5:119
# new not in old 149: 9:21
# new not in old 150: 9:72
# new not in old 151: 9:89
# new not in old 152: 9:100
#
# Number of ayahs: 152
#
# query left at 68:2 : مَجْنُون ()
#
# query left at 68:34 : جنن ((?:[Pp]aradise|[Gg]arden|[Hh]eaven))
#
# query left at 114:6 : جِنَّة ()
#
# query left at 7:38 : جِنّ ()
#
# query left at 72:6 : عوذ جِنّ ( )
#
# query left at 27:10 : جَآنّ ((?:[Ss]nake|[Rr]eptile|[Vv]iper))
#
# query left at 27:10 : جنن (^((?![Pp]aradise|[Gg]arden|[Hh]eaven|[Mm]ad|[Cc]raz|[Dd]emon|[Dd]evil|[Jj]inn).)*$)
#
# query left at 27:39 : جِنّ عِفْرِيت ( )
#
# query left at 15:27 : جَآنّ (^((?![Ss]nake|[Rr]eptile|[Vv]iper).)*$)
#
# query left at 6:76 : جنن ()
#
# query left at 6:100 : جِنّ شرك ( )
#
# query left at 6:111 : جِنّ مَلَك ( )
#
# query left at 6:112 : جِنّ شطن ( )
#
# query left at 6:128 : جِنّ ولي ( )
#
# query left at 37:158 : جِنَّة نسب ( )
#
# query left at 34:41 : جِنّ عبد ( )
#
# query left at 41:25 : جِنّ قَرِين ( )
#
# query left at 18:50 : جِنّ ذرر إِبْلِيس (  )
#
# query left at 18:50 : جِنّ إِبْلِيس ( )
#
# query left at 52:29 : جنن كهن ( )

# %%
import re

re.findall("")
# Out:
# 'aaaabaaa'
