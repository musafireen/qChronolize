# %% [markdown]
# # save qchronolyze analysis to md

# %%
from qChronolyze import *

# %%
import csv
with open('data/lemmata.tsv') as f:
    lemmata = [row for row in csv.DictReader(f, delimiter='\t') ]
    # lem = f.read()

print(lemmata[1]['Buckwalter'])
# print(lem)
# Out:
# {ll~ah

# %%
from aggregates import *

# %%
{i: shirk[i] for i in range(len(shirk)) if shirk[i][0]["strL"][0]["stri"] == "$ms"}
# Out:
# {74: [{'wrdDis': 0,
#    'strL': [{'stri': '$ms', 'flt': ''},
#     {'stri': 'rab~', 'flt': ''},
#     {'stri': 'ha`*aA', 'flt': ''}]}],
#  75: [{'wrdDis': 0,
#    'strL': [{'stri': '$ms', 'flt': ''},
#     {'stri': 'sjd', 'flt': ''},
#     {'stri': 'dwn', 'flt': ''}]}],
#  76: [{'wrdDis': 0,
#    'strL': [{'stri': '$ms', 'flt': ''},
#     {'stri': 'sjd', 'flt': ''},
#     {'stri': 'laA', 'flt': ''},
#     {'stri': 'Ebd', 'flt': ''}]}]}

# %%
qL = [
 [
    {
      "wrdDis": 1,
      "strL": [
        { "stri": "huwa", "strTyp": "PRON", "flt": "",},
        # { "stri": "Alh", "flt": "(?:^((?!Allah).)*$)",},
        { "stri": "dwn", "flt": "(?:other|esides|exclud|Us|instead)",},
      ],
    },
  ],
]

# %%
from qChronolyze import querize

querize(
    
    ### uncomment whichever concept you want to display

    [
        *qL,
        # [{'wrdDis': 0, 'strL': [{'stri': 'maAruwt', 'flt': 'marut'}]}],
        # {'TwE': '(?<!be )[Oo]bey'},
        # *angels,
        # *jinn
        # *spirituals,
        # *shirk,
        # *salah
        # *mamluk_yaman
        # *nisa
        # *ahl_kitab
        # *jhd
        # *ruh
        # *fadl
        # *zann,
        # shirk[79],
        # *foreign_vocabs
        
    ],
    
    ### uncomment chosen name for saved obsidian md file
     
    # 'zann',
    # 'spirituals',
    # 'firawn_taghut',
    # 'fadl',
    # 'ruh',
    # 'jhd_qtl',
    # 'ahl_kitab',
    # 'firawn_taghut',
    # 'nisa',
    # 'mamluk_yaman',
    # 'salah',
    # 'obedience',
    # 'shirk',
    # 'iman_islam',
    # "anbiya",
    # "foreign_vocab",
    # "animals",

    ### uncomment chosen tafsir reference language for linking
    # 'Arabic',
    refLng = 'arabic',
    # 'Bengali',
    # /
    # '1',

    ### uncomment chosen presentation style
    # pres='table',
    pres='table',

    )
# Out:
# <style type="text/css">
# #T_8af19_row0_col0, #T_8af19_row0_col1, #T_8af19_row0_col2, #T_8af19_row0_col3, #T_8af19_row0_col4, #T_8af19_row0_col5, #T_8af19_row0_col6, #T_8af19_row2_col0, #T_8af19_row2_col1, #T_8af19_row2_col2, #T_8af19_row2_col3, #T_8af19_row2_col4, #T_8af19_row2_col5, #T_8af19_row2_col6, #T_8af19_row4_col0, #T_8af19_row4_col1, #T_8af19_row4_col2, #T_8af19_row4_col3, #T_8af19_row4_col4, #T_8af19_row4_col5, #T_8af19_row4_col6, #T_8af19_row10_col0, #T_8af19_row10_col1, #T_8af19_row10_col2, #T_8af19_row10_col3, #T_8af19_row10_col4, #T_8af19_row10_col5, #T_8af19_row10_col6, #T_8af19_row23_col0, #T_8af19_row23_col1, #T_8af19_row23_col2, #T_8af19_row23_col3, #T_8af19_row23_col4, #T_8af19_row23_col5, #T_8af19_row23_col6, #T_8af19_row35_col0, #T_8af19_row35_col1, #T_8af19_row35_col2, #T_8af19_row35_col3, #T_8af19_row35_col4, #T_8af19_row35_col5, #T_8af19_row35_col6, #T_8af19_row41_col0, #T_8af19_row41_col1, #T_8af19_row41_col2, #T_8af19_row41_col3, #T_8af19_row41_col4, #T_8af19_row41_col5, #T_8af19_row41_col6, #T_8af19_row52_col0, #T_8af19_row52_col1, #T_8af19_row52_col2, #T_8af19_row52_col3, #T_8af19_row52_col4, #T_8af19_row52_col5, #T_8af19_row52_col6, #T_8af19_row56_col0, #T_8af19_row56_col1, #T_8af19_row56_col2, #T_8af19_row56_col3, #T_8af19_row56_col4, #T_8af19_row56_col5, #T_8af19_row56_col6, #T_8af19_row57_col0, #T_8af19_row57_col1, #T_8af19_row57_col2, #T_8af19_row57_col3, #T_8af19_row57_col4, #T_8af19_row57_col5, #T_8af19_row57_col6, #T_8af19_row75_col0, #T_8af19_row75_col1, #T_8af19_row75_col2, #T_8af19_row75_col3, #T_8af19_row75_col4, #T_8af19_row75_col5, #T_8af19_row75_col6 {
#   background-color: rgb(100,220,20);
#   foreground-color: black;
#   color: black;
#   opacity: 1;
# }
# #T_8af19_row1_col0, #T_8af19_row1_col1, #T_8af19_row1_col2, #T_8af19_row1_col3, #T_8af19_row1_col4, #T_8af19_row1_col5, #T_8af19_row1_col6, #T_8af19_row3_col0, #T_8af19_row3_col1, #T_8af19_row3_col2, #T_8af19_row3_col3, #T_8af19_row3_col4, #T_8af19_row3_col5, #T_8af19_row3_col6, #T_8af19_row5_col0, #T_8af19_row5_col1, #T_8af19_row5_col2, #T_8af19_row5_col3, #T_8af19_row5_col4, #T_8af19_row5_col5, #T_8af19_row5_col6, #T_8af19_row7_col0, #T_8af19_row7_col1, #T_8af19_row7_col2, #T_8af19_row7_col3, #T_8af19_row7_col4, #T_8af19_row7_col5, #T_8af19_row7_col6, #T_8af19_row8_col0, #T_8af19_row8_col1, #T_8af19_row8_col2, #T_8af19_row8_col3, #T_8af19_row8_col4, #T_8af19_row8_col5, #T_8af19_row8_col6, #T_8af19_row9_col0, #T_8af19_row9_col1, #T_8af19_row9_col2, #T_8af19_row9_col3, #T_8af19_row9_col4, #T_8af19_row9_col5, #T_8af19_row9_col6, #T_8af19_row11_col0, #T_8af19_row11_col1, #T_8af19_row11_col2, #T_8af19_row11_col3, #T_8af19_row11_col4, #T_8af19_row11_col5, #T_8af19_row11_col6, #T_8af19_row12_col0, #T_8af19_row12_col1, #T_8af19_row12_col2, #T_8af19_row12_col3, #T_8af19_row12_col4, #T_8af19_row12_col5, #T_8af19_row12_col6, #T_8af19_row14_col0, #T_8af19_row14_col1, #T_8af19_row14_col2, #T_8af19_row14_col3, #T_8af19_row14_col4, #T_8af19_row14_col5, #T_8af19_row14_col6, #T_8af19_row15_col0, #T_8af19_row15_col1, #T_8af19_row15_col2, #T_8af19_row15_col3, #T_8af19_row15_col4, #T_8af19_row15_col5, #T_8af19_row15_col6, #T_8af19_row16_col0, #T_8af19_row16_col1, #T_8af19_row16_col2, #T_8af19_row16_col3, #T_8af19_row16_col4, #T_8af19_row16_col5, #T_8af19_row16_col6, #T_8af19_row17_col0, #T_8af19_row17_col1, #T_8af19_row17_col2, #T_8af19_row17_col3, #T_8af19_row17_col4, #T_8af19_row17_col5, #T_8af19_row17_col6, #T_8af19_row18_col0, #T_8af19_row18_col1, #T_8af19_row18_col2, #T_8af19_row18_col3, #T_8af19_row18_col4, #T_8af19_row18_col5, #T_8af19_row18_col6, #T_8af19_row19_col0, #T_8af19_row19_col1, #T_8af19_row19_col2, #T_8af19_row19_col3, #T_8af19_row19_col4, #T_8af19_row19_col5, #T_8af19_row19_col6, #T_8af19_row20_col0, #T_8af19_row20_col1, #T_8af19_row20_col2, #T_8af19_row20_col3, #T_8af19_row20_col4, #T_8af19_row20_col5, #T_8af19_row20_col6, #T_8af19_row21_col0, #T_8af19_row21_col1, #T_8af19_row21_col2, #T_8af19_row21_col3, #T_8af19_row21_col4, #T_8af19_row21_col5, #T_8af19_row21_col6, #T_8af19_row22_col0, #T_8af19_row22_col1, #T_8af19_row22_col2, #T_8af19_row22_col3, #T_8af19_row22_col4, #T_8af19_row22_col5, #T_8af19_row22_col6, #T_8af19_row24_col0, #T_8af19_row24_col1, #T_8af19_row24_col2, #T_8af19_row24_col3, #T_8af19_row24_col4, #T_8af19_row24_col5, #T_8af19_row24_col6, #T_8af19_row25_col0, #T_8af19_row25_col1, #T_8af19_row25_col2, #T_8af19_row25_col3, #T_8af19_row25_col4, #T_8af19_row25_col5, #T_8af19_row25_col6, #T_8af19_row26_col0, #T_8af19_row26_col1, #T_8af19_row26_col2, #T_8af19_row26_col3, #T_8af19_row26_col4, #T_8af19_row26_col5, #T_8af19_row26_col6, #T_8af19_row27_col0, #T_8af19_row27_col1, #T_8af19_row27_col2, #T_8af19_row27_col3, #T_8af19_row27_col4, #T_8af19_row27_col5, #T_8af19_row27_col6, #T_8af19_row32_col0, #T_8af19_row32_col1, #T_8af19_row32_col2, #T_8af19_row32_col3, #T_8af19_row32_col4, #T_8af19_row32_col5, #T_8af19_row32_col6, #T_8af19_row33_col0, #T_8af19_row33_col1, #T_8af19_row33_col2, #T_8af19_row33_col3, #T_8af19_row33_col4, #T_8af19_row33_col5, #T_8af19_row33_col6, #T_8af19_row37_col0, #T_8af19_row37_col1, #T_8af19_row37_col2, #T_8af19_row37_col3, #T_8af19_row37_col4, #T_8af19_row37_col5, #T_8af19_row37_col6, #T_8af19_row39_col0, #T_8af19_row39_col1, #T_8af19_row39_col2, #T_8af19_row39_col3, #T_8af19_row39_col4, #T_8af19_row39_col5, #T_8af19_row39_col6, #T_8af19_row40_col0, #T_8af19_row40_col1, #T_8af19_row40_col2, #T_8af19_row40_col3, #T_8af19_row40_col4, #T_8af19_row40_col5, #T_8af19_row40_col6, #T_8af19_row42_col0, #T_8af19_row42_col1, #T_8af19_row42_col2, #T_8af19_row42_col3, #T_8af19_row42_col4, #T_8af19_row42_col5, #T_8af19_row42_col6, #T_8af19_row45_col0, #T_8af19_row45_col1, #T_8af19_row45_col2, #T_8af19_r ...

# %%
from qChronoMd import qChronoMd

qChronoMd(
    jinn
### enter pair of word/root and meaning filtering regex as key-value pair dictionary
# {
#    '$Tn':  # english word / transliterated root https://corpus.quran.com/java/buckwalter.jsp
#     '',   # regex filter for meaning
#     'jnn':
#     'jinn'
# },

### tafsir reference language
# 'Arabic',
# /
# '1',

### presentation style
# pres='plot',
    ,
    "jinn"
    # "makan"
    ,
    "arabic"

)

# %%
from qChronoMd import qChronoMd

qChronoMd(
    
    ### uncomment whichever concept you want to save

    [
        # {'TwE': '(?<!be )[Oo]bey'},
        # *spirituals,
        # *shirk2,
        *jinn,
        # *salah
        # *mamluk_yaman
        # *nisa
        # *ahl_kitab
        # *jhd
        # *ruh
        # *fadl
        # *zann,
        # *animals,
        # *foreign_vocabs
        
    ],
    
    ### uncomment chosen filename for saving in markdown format for obsidian
     
    # 'zann',
    # 'spirituals',
    # 'firawn_taghut',
    # 'fadl',
    # 'ruh',
    # 'jhd_qtl',
    # 'ahl_kitab',
    # 'firawn_taghut',
    # 'nisa',
    # 'mamluk_yaman',
    # 'salah2',
    # 'obedience',
    # 'shirk4',
    "jinn",
    # 'iman_islam',
    # "anbiya",
    # "foreign_vocab",
    # "animals",

    ### uncomment chosen tafsir reference for linking in file
    # "ar-tafsir-al-tabari",
    # "bn-tafseer-ibn-e-kaseer",
    "arabic",

)
# Out:
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ap flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ap flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jaA^n~ flt: (?:[Ss]nake|[Rr]eptile|[Vv]iper) strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jaA^n~ flt: (?:[Ss]nake|[Rr]eptile|[Vv]iper) strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jaA^n~ flt: ^((?![Ss]nake|[Rr]eptile|[Vv]iper).)*$ strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jaA^n~ flt: ^((?![Ss]nake|[Rr]eptile|[Vv]iper).)*$ strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  khn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  khn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  malak flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  malak flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Eiforiyt flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Eiforiyt flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  qariyn flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  qariyn flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  *rr flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  *rr flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  <iboliys flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  <iboliys flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  <iboliys flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  <iboliys flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  $Tn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Tn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  majonuwn flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  majonuwn flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt:  strTyp: root frm: None poSp: V inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt:  strTyp: root frm: All poSp: V inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt: (?:[Pp]aradise|[Gg]arden|[Hh]eaven) strTyp: root frm: root poSp: N inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt: (?:[Pp]aradise|[Gg]arden|[Hh]eaven) strTyp: root frm: root poSp: N inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt: ^((?![Pp]aradise|[Gg]arden|[Hh]eaven|[Mm]ad|[Cc]raz|[Dd]emon|[Dd]evil|[Jj]inn).)*$ strTyp: root frm: root poSp: N inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt: ^((?![Pp]aradise|[Gg]arden|[Hh]eaven|[Mm]ad|[Cc]raz|[Dd]emon|[Dd]evil|[Jj]inn).)*$ strTyp: root frm: root poSp: N inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Ew* flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ew* flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  wly flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wly flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  $rk flt:  strTyp: root frm: None poSp: N inpLng: None inpSch: None
# props set in str init:  stri:  $rk flt:  strTyp: root frm: All poSp: N inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ebd flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ebd flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ap flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ap flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  nsb flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nsb flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# [<qChronolyze.combClass object at 0x7efe882070a0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe882070a0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.json: lenght 0'
# [<qChronolyze.combClass object at 0x7efe882070d0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe882070d0>
# optStInsts after comb: []
# for string: jin~ap
# file found for jin~ap
# Successfully loaded data from 'data/cache/arb/جِنَّة/lem/All/All.json: lenght 10'
# [<qChronolyze.combClass object at 0x7efe88207190>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe88207190>
# optStInsts after comb: []
# for string: jaA^n~
# file found for jaA^n~
# Successfully loaded data from 'data/cache/arb/جَآنّ/lem/All/All.json: lenght 7'
# [<qChronolyze.combClass object at 0x7efe882071f0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe882071f0>
# optStInsts after comb: []
# for string: jaA^n~
# file found for jaA^n~
# Successfully loaded data from 'data/cache/arb/جَآنّ/lem/All/All.json: lenght 7'
# [<qChronolyze.combClass object at 0x7efe882072b0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe882072b0>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/All/All/All.json: lenght 201'
# for string: khn
# file found for khn
# Successfully loaded data from 'data/cache/arb/كهن/All/All/All.json: lenght 2'
# [<qChronolyze.combClass object at 0x7efe88207490>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe88207490>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.json: lenght 0'
# for string: malak
# file found for malak
# Successfully loaded data from 'data/cache/arb/مَلَك/lem/All/All.json: lenght 88'
# [<qChronolyze.combClass object at 0x7efe88207430>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe88207430>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.json: lenght 0'
# for string: Eiforiyt
# file found for Eiforiyt
# Successfully loaded data from 'data/cache/arb/عِفْرِيت/lem/All/All.json: lenght 1'
# [<qChronolyze.combClass object at 0x7efe882073a0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe882073a0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.json: lenght 0'
# for string: qariyn
# file found for qariyn
# Successfully loaded data from 'data/cache/arb/قَرِين/lem/All/All.json: lenght 8'
# [<qChronolyze.combClass object at 0x7efe88207550>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe88207550>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.json: lenght 0'
# for string: *rr
# file found for *rr
# Successfully loaded data from 'data/cache/arb/ذرر/root/All/All.json: lenght 38'
# for string: <iboliys
# file found for <iboliys
# Successfully loaded data from 'data/cache/arb/إِبْلِيس/lem/All/All.json: lenght 11'
# [<qChronolyze.combClass object at 0x7efe882075b0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe882075b0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.json: lenght 0'
# for string: <iboliys
# file found for <iboliys
# Successfully loaded data from 'data/cache/arb/إِبْلِيس/lem/All/All.json: lenght 11'
# [<qChronolyze.combClass object at 0x7efe88207640>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe88207640>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.json: lenght 0'
# for string: $Tn
# file found for $Tn
# Successfully loaded data from 'data/cache/arb/شطن/All/All/All.json: lenght 88'
# [<qChronolyze.combClass object at 0x7efe882079d0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe882079d0>
# optStInsts after comb: []
# for string: majonuwn
# file found for majonuwn
# Successfully loaded data from 'data/cache/arb/مَجْنُون/lem/All/All.json: lenght 11'
# [<qChronolyze.combClass object at 0x7efe882079a0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe882079a0>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/root/All/V.json: lenght 1'
# [<qChronolyze.combClass object at 0x7efe882076a0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe882076a0>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/root/root/N.json: lenght 149'
# [<qChronolyze.combClass object at 0x7efe88207790>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe88207790>
# optStInsts after comb: []
# for string: jnn
# file found for jnn
# Successfully loaded data from 'data/cache/arb/جنن/root/root/N.json: lenght 149'
# [<qChronolyze.combClass object at 0x7efe88207a60>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe88207a60>
# optStInsts after comb: []
# for string: Ew*
# file found for Ew*
# Successfully loaded data from 'data/cache/arb/عوذ/All/All/All.json: lenght 17'
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.json: lenght 0'
# [<qChronolyze.combClass object at 0x7efe88207af0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe88207af0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.json: lenght 0'
# for string: wly
# file found for wly
# Successfully loaded data from 'data/cache/arb/ولي/All/All/All.json: lenght 232'
# [<qChronolyze.combClass object at 0x7efe88207b50>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe88207b50>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.json: lenght 0'
# for string: $rk
# file found for $rk
# Successfully loaded data from 'data/cache/arb/شرك/root/All/N.json: lenght 96'
# [<qChronolyze.combClass object at 0x7efe88207bb0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe88207bb0>
# optStInsts after comb: []
# for string: jin~
# file found for jin~
# Successfully loaded data from 'data/cache/arb/جِنّ/lem/All/All.json: lenght 0'
# for string: Ebd
# file found for Ebd
# Successfully loaded data from 'data/cache/arb/عبد/All/All/All.json: lenght 275'
# [<qChronolyze.combClass object at 0x7efe88207c70>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7efe88207c70>
# optStInsts after comb: []
# for string: jin~ap
# file found for jin~ap
# Successfully loaded data from 'data/cache/arb/جِنَّة/lem/All/All.json: lenght 10'
# for string: nsb
# file found for nsb
# Successfully loaded data from 'data/cache/arb/نسب/All/All/All.json: lenght 3'
#
# total 128 instances found
# 'sorter.json' found'
# last item in sorter: 110:3
# successfully loaded sorter of length 6236 from 'sorter.json'
# for 81:13 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 1: 81:13
# for 50:31 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 2: 50:31
# for 7:19 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 3: 7:19
# for 7:22 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 4: 7:22
# for 7:27 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 5: 7:27
# for 7:38 secondaries:  ['\n## جِنّ ()\n\n', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 6: 7:38
# for 7:40 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 7: 7:40
# for 7:42 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 8: 7:42
# for 7:43 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 9: 7:43
# for 7:44 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 10: 7:44
# for 7:46 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 11: 7:46
# for 7:49 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 12: 7:49
# for 7:50 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 13: 7:50
# for 7:179 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 14: 7:179
# for 72:1 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 15: 72:1
# for 72:5 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 16: 72:5
# for 72:6 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 17: 72:6
# for 36:26 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 18: 36:26
# for 36:55 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 19: 36:55
# for 25:24 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 20: 25:24
# for 19:60 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 21: 19:60
# for 19:63 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 22: 19:63
# for 20:117 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 23: 20:117
# for 20:121 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 24: 20:121
# for 26:90 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 25: 26:90
# for 27:17 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 26: 27:17
# for 27:39 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## جِنّ عِفْرِيت ( )\n\n', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 27: 27:39
# for 17:88 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 28: 17:88
# for 10:26 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 29: 10:26
# for 11:23 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 30: 11:23
# for 11:108 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 31: 11:108
# for 6:100 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 32: 6:100
# for 6:111 secondaries:  ['\n## جِنّ مَلَك ( )\n\n']
#
# old not in new 33: 6:111
# for 6:112 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جِنّ مَلَك ( )\n\n\n[[#6:111]]', '\n## جِنّ شطن ( )\n\n', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 34: 6:112
# for 6:128 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 35: 6:128
# for 6:130 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 36: 6:130
# for 34:12 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 37: 34:12
# for 34:14 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 38: 34:14
# for 34:40 secondaries:  ['\n## >>> جِنّ مَلَك ( )\n\n\n[[#6:111]]']
#
# old not in new 39: 34:40
# for 34:41 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جِنّ مَلَك ( )\n\n\n[[#6:111]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 40: 34:41
# for 39:73 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 41: 39:73
# for 39:74 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 42: 39:74
# for 40:40 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 43: 40:40
# for 41:25 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## جِنّ قَرِين ( )\n\n', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 44: 41:25
# for 41:29 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جِنّ مَلَك ( )\n\n\n[[#6:111]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 45: 41:29
# for 41:30 secondaries:  ['\n## >>> جِنّ مَلَك ( )\n\n\n[[#6:111]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 46: 41:30
# for 42:7 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 47: 42:7
# for 43:70 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 48: 43:70
# for 43:72 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 49: 43:72
# for 46:14 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 50: 46:14
# for 46:16 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 51: 46:16
# for 46:18 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 52: 46:18
# for 46:29 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 53: 46:29
# for 51:56 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 54: 51:56
# for 18:50 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جِنّ مَلَك ( )\n\n\n[[#6:111]]', '\n## جِنّ إِبْلِيس ( )\n\n', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 55: 18:50
# for 16:32 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 56: 16:32
# for 79:41 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 57: 79:41
# for 29:58 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 58: 29:58
# for 2:35 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 59: 2:35
# for 2:82 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 60: 2:82
# for 2:111 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 61: 2:111
# for 2:214 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 62: 2:214
# for 2:221 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 63: 2:221
# for 3:142 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 64: 3:142
# for 3:185 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 65: 3:185
# for 4:124 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 66: 4:124
# for 47:6 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 67: 47:6
# for 47:15 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 68: 47:15
# for 13:35 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 69: 13:35
# for 55:33 secondaries:  ['\n## >>> جِنّ ()\n\n\n[[#7:38]]', '\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 70: 55:33
# for 59:20 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 71: 59:20
# for 66:11 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 72: 66:11
# for 5:72 secondaries:  ['\n## >>> جنن ()\n\n\n[[#68:2]]']
#
# old not in new 73: 5:72
# for 9:111 secondaries:  ['\n## >>> جنن ()\n[[#68:2]]']
#
# old not in new 74: 9:111
#
# Number of ayahs: 198
#
# query left at 68:2 : مَجْنُون ()
#
# query left at 68:2 : جنن ()
#
# query left at 68:34 : جنن ((?:[Pp]aradise|[Gg]arden|[Hh]eaven))
#
# query left at 114:6 : جِنَّة ()
#
# query left at 7:38 : جِنّ ()
#
# query left at 27:10 : جَآنّ ((?:[Ss]nake|[Rr]eptile|[Vv]iper))
#
# query left at 27:10 : جنن (^((?![Pp]aradise|[Gg]arden|[Hh]eaven|[Mm]ad|[Cc]raz|[Dd]emon|[Dd]evil|[Jj]inn).)*$)
#
# query left at 27:10 : جَآنّ ()
#
# query left at 27:39 : جِنّ عِفْرِيت ( )
#
# query left at 15:27 : جَآنّ (^((?![Ss]nake|[Rr]eptile|[Vv]iper).)*$)
#
# query left at 6:111 : جِنّ مَلَك ( )
#
# query left at 6:112 : جِنّ شطن ( )
#
# query left at 37:158 : جِنَّة نسب ( )
#
# query left at 41:25 : جِنّ قَرِين ( )
#
# query left at 18:50 : جِنّ إِبْلِيس ( )
#
# query left at 52:29 : جنن كهن ( )

# %%
"aaaabaaa".replace("aca","")
# Out:
# 'aaaabaaa'
