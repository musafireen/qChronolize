# %%
'a' not in []
# Out:
# True

# %%
flnm = 'firawn_taghut'

mdFile = f'data/compare/{flnm}.md'

import re

with open(mdFile) as f:
    strn = f.read()

rep = re.compile(
        '\n#\s*(?:Q\:){0,1}(\d{1,}\:\d{1,})(.*?(?=\n#|$))(?:(\n##\s{1,}.*?(?=\n#\s{1,}|$))){0,1}',
        re.DOTALL
    ).findall(

    strn
)


print(len(rep))

repDic = { 
    setty[0]: { 
        'string' : setty[1] , 
        'queries': [
            {
                'query': quer[0],
                'postquery': quer[1],
            
            }
            # quer
            for quer in re.compile(
                '\n##\s{1,}([^\n]{1,}(?=\n))(.*?(?=\n))',    
                re.DOTALL,
            ).findall(
                setty[2] 
            )
        ]
            if len(setty) > 2 else None 
    }
    for setty in rep 
}

print(repDic)
# Out:
# 103
# {'96:6': {'string': '\n\n[Q.96:6](https://quran.com/96:6/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#96:6]]\n', 'queries': [{'query': 'Tgy ()', 'postquery': ''}]}, '73:15': {'string': '\n\n[Q.73:15](https://quran.com/73:15/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#73:15]]\n', 'queries': [{'query': 'firoEawn ()', 'postquery': ''}]}, '73:16': {'string': '\n\n[Q.73:16](https://quran.com/73:16/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#73:16]]\n', 'queries': []}, '89:10': {'string': '\n\n[Q.89:10](https://quran.com/89:10/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#89:10]]\n', 'queries': []}, '89:11': {'string': '\n\n[Q.89:11](https://quran.com/89:11/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#89:11]]\n', 'queries': []}, '53:17': {'string': '\n\n[Q.53:17](https://quran.com/53:17/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#53:17]]\n', 'queries': []}, '53:52': {'string': '\n\n[Q.53:52](https://quran.com/53:52/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#53:52]]\n', 'queries': []}, '91:11': {'string': '\n\n[Q.91:11](https://quran.com/91:11/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#91:11]]\n', 'queries': []}, '85:18': {'string': '\n\n[Q.85:18](https://quran.com/85:18/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#85:18]]\n', 'queries': []}, '50:13': {'string': '\n\n[Q.50:13](https://quran.com/50:13/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#50:13]]\n', 'queries': []}, '50:27': {'string': '\n\n[Q.50:27](https://quran.com/50:27/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#50:27]]\n', 'queries': []}, '54:41': {'string': '\n\n[Q.54:41](https://quran.com/54:41/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#54:41]]\n', 'queries': []}, '38:12': {'string': '\n\n[Q.38:12](https://quran.com/38:12/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#38:12]]\n', 'queries': []}, '38:55': {'string': '\n\n[Q.38:55](https://quran.com/38:55/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#38:55]]\n', 'queries': []}, '7:103': {'string': '\n\n[Q.7:103](https://quran.com/7:103/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#7:103]]\n', 'queries': []}, '7:104': {'string': '\n\n[Q.7:104](https://quran.com/7:104/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#7:104]]\n', 'queries': []}, '7:109': {'string': '\n\n[Q.7:109](https://quran.com/7:109/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#7:109]]\n', 'queries': []}, '7:113': {'string': '\n\n[Q.7:113](https://quran.com/7:113/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#7:113]]\n', 'queries': []}, '7:123': {'string': '\n\n[Q.7:123](https://quran.com/7:123/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#7:123]]\n', 'queries': []}, '7:127': {'string': '\n\n[Q.7:127](https://quran.com/7:127/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#7:127]]\n', 'queries': []}, '7:130': {'string': '\n\n[Q.7:130](https://quran.com/7:130/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#7:130]]\n', 'queries': []}, '7:137': {'string': '\n\n[Q.7:137](https://quran.com/7:137/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#7:137]]\n', 'queries': []}, '7:141': {'string': '\n\n[Q.7:141](https://quran.com/7:141/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#7:141]]\n', 'queries': []}, '7:186': {'string': '\n\n[Q.7:186](https://quran.com/7:186/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#7:186]]\n', 'queries': []}, '20:24': {'string': '\n\n[Q.20:24](https://quran.com/20:24/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#20:24]]\n', 'queries': [{'query': 'firoEawn Tgy ( )', 'postquery': ''}]}, '20:43': {'string': '\n\n[Q.20:43](https://quran.com/20:43/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#20:43]]\n', 'queries': []}, '20:45': {'string': '\n\n[Q.20:45](https://quran.com/20:45/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#20:45]]\n', 'queries': []}, '20:60': {'string': '\n\n[Q.20:60](https://quran.com/20:60/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#20:60]]\n', 'queries': []}, '20:78': {'string': '\n\n[Q.20:78](https://quran.com/20:78/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#20:78]]\n', 'queries': []}, '20:79': {'string': '\n\n[Q.20:79](https://quran.com/20:79/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#20:79]]\n', 'queries': []}, '20:81': {'string': '\n\n[Q.20:81](https ...

# %%
import re

with open("/mnt/f/Documents/notes/Ref/iamb.mystery3.md") as f:
    strn1 = f.read()

matches1 = re.compile(
    # '[#]{1,}\s*[c]{0,1}\d{1,}(?:\.{0,1})\d{0,}\n'
    # 'subtype="sec'
    # '\n#{1,2}\s*[c]{0,1}(\d{1,})\.{0,1}(\d{0,})\n(.*?(?=\n#|$))',
    '\n#{1,2}\s*(\d{1,})\.(\d{1,})(.*?(?=\n#|$))',
    re.DOTALL
).findall(
    strn1
)


with open("/mnt/f/Documents/notes/Ref/iamb.myst/096.html") as f:
    strn2 = f.read()

matches2 = re.compile(
    # '[#]{1,}\s*[c]{0,1}\d{1,}(?:\.{0,1})\d{0,}\n'
    # 'subtype="sec'
    # '\n#{1,2}\s*[c]{0,1}(\d{1,})\.{0,1}(\d{0,})\n(.*?(?=\n#|$))',
    'CHAP\.\s[0IVX]*(.*?)(?=CHAP\.\s|$)',
    re.DOTALL
).findall(
    strn2
)

# n = 94
print(
    len(matches1),
    len(matches2)
    #   +n
      )

# matches1
strNew = ''
for n in range(len(matches1)):
    # if n == len(matches1)-1:
        # print(
        #     matches1[n],
        #     matches2[n]
        #     )
    strNew += f'\n\n## {matches1[n][0]}.{matches1[n][1]}\n{matches1[n][2]}\n{matches2[n]}'

# print(strNew)
with open('/mnt/f/Documents/notes/Ref/iamb.myst4.md', 'w') as f:
    f.write(strNew)
# Out:
# 141 141

# %%
import re

with open('/mnt/f/Documents/notes/Ref/iamb.MEg.md') as f:
    strn1 = f.read()

matches = re.compile(
    '\n##\s\d*\.\d*'
).findall(
    strn1
)

len(matches)
# Out:
# 141

# %%
import re

with open("/mnt/f/Documents/notes/Ref/iamb.MEg.md") as f:
    strn1 = f.read()

matches = re.compile(
    '(\n##\s\d*\.\d*\n)([^#a-zA-Z]*?(?=[a-zA-Z]))([^#]*(?=\n#|$))',
    re.DOTALL
).findall(
    strn1
)

print(
    # matches
    len(matches)
)

strnNew = ''

for match in matches:
    strnNew += match[0]
    secs = re.compile(
        # '[#]{1,}\s*[c]{0,1}\d{1,}(?:\.{0,1})\d{0,}\n'
        # 'subtype="sec'
        # '\n#{1,2}\s*[c]{0,1}(\d{1,})\.{0,1}(\d{0,})\n(.*?(?=\n#|$))',
        '([^#\.0-9a-zA-Z]{1,}\.)',
        re.DOTALL
    ).findall(
        match[1]
    )

    # print(secs)

    matchUpd = ''
    for n in range(len(secs)):
        secu = secs[n].strip('\n').strip(' ')
        matchUpd += f'\n\n### {n+1}\n\n#### gr\n\n{secu}\n\n#### en\n\n#### sn\n\n{secu}\n\n#### ar\n\n{secu}\n\n'
    
    # print('--------------------', matchUpd)

    strnNew += matchUpd

    strnNew += match[2]
# ).sub(
#     '### \n#### gr\\1\n\n#### en \n\n#### sn\n\n\\1\n\n#### ar\n\n\\1',
#     strn1
# )

# matches1
# strn1
with open('/mnt/f/Documents/notes/Ref/iamb.MEg2.md', 'w') as f:
    f.write(strnNew)
# Out:
# 139

# %%
# from qChronolyze import filtDown, getSorter
from qChronolyze import aggregLsts, getSorter

def qChronoMd(dicti,flnm,tafs):
    mdFile = f'data/compare/{flnm}.md'
    # instLstAgg = []
    queriesLeft = { f'{list(item.keys())[0]} ({list(item.values())[0]})' for item in dicti }
    alreadyRefed = []
    instLstAgg = aggregLsts(dicti,tafs)

    import pandas as pd

    df = pd.DataFrame(instLstAgg)
    sorter = getSorter()
    df['surah:ayah'] = pd.Categorical(df['surah:ayah'], categories=sorter, ordered=True)
    df.sort_values(["surah:ayah","position"],inplace=True)
    # df.reset_index(drop=True,inplace=True)
    sortedRecs = df.to_dict(orient='records')


    repDic = {}

    for rec in sortedRecs:
        if rec["surah:ayah"] not in repDic.keys():
            repDic[rec["surah:ayah"]] = {
                'string': f'\n[Q.{rec["surah:ayah"]}](https://quran.com/{rec["surah:ayah"]}/tafsirs/{tafs})\n'
                            + f'\n![[Qrsed#{rec["surah:ayah"]}]]\n',
                'queries': [
                    {
                        'query': rec["query"],
                        'postquery': ''
                    }
                ]
            }
        else:
            repDic[rec["surah:ayah"]]["queries"].append(
                {
                    'query': rec["query"], 
                    'postquery': '',
                }
            )


    print('\nrepDic before checking md: ', repDic, '\n')

    import re

    with open(mdFile) as f:
        strn = f.read()

    rep = re.compile(
            '\n#\s*(?:Q\:){0,1}(\d{1,}\:\d{1,})(.*?(?=\n#|$))(?:(\n##\s{1,}.*?(?=\n#\s{1,}|$))){0,1}',
            re.DOTALL
        ).findall(

        strn
    )


    # print(len(rep))

    for setty in rep:
        if setty[0] not in repDic:
            repDic[setty[0]] = { 
                'string' : setty[1] , 
                'queries': [
                    {
                        'query': quer[0],
                        'postquery': quer[1],
                    
                    }
                    # quer
                    for quer in re.compile(
                        '\n##\s{1,}([^\n]{1,}(?=\n))(.*?(?=\n))',    
                        re.DOTALL,
                    ).findall(
                        setty[2] 
                    )
                ]
                    if len(setty) > 2 else None 
            }
        else:
           for quer in re.compile(
                        '\n##\s{1,}([^\n]{1,}(?=\n))(.*?(?=\n))',    
                        re.DOTALL,
                    ).findall(
                        setty[2] 
                    ):
                repDic[setty[0]]['queries'].append({
                        'query': quer[0],
                        'postquery': quer[1],
                    
                    })
        

    print('\nrepDic after checking md: ', repDic, '\n')
    # print(repDic)

    sorterIdxs = [sorter.index(suray) for suray in repDic.keys()]

    surAyOrdered = [sorter[idx] for idx in sorterIdxs]
    
    newStr = ''

    for surAy in surAyOrdered:       
        newStrUp =   f'\n# Q:{surAy}\n' + f'\n[Q.{surAy}](https://quran.com/{surAy}/tafsirs/{tafs})\n' + f'\n![[Qrsed#{surAy}]]\n'

        newStr += newStrUp

        alreadyRefed.append(rec["surah:ayah"])
        for query in repDic[surAy]['queries']:
            if query['query'] in queriesLeft:
                print(f'\nquery left at {surAy} : {query["query"]}')
                newStrUp = f'\n## {query["query"]}\n' + query['postquery']
                newStr += newStrUp
                queriesLeft.remove(query["query"])

    with open(mdFile, 'w') as f:
        f.write(newStr)

# %% [markdown]
# # try

# %%
qChronoMd(
    [
        {'Tgy': ''},
        {'firoEawn': ''},
        {'firoEawn Tgy': ' '},
        {'TaAguwt': ''},
    ],
    'firawn_taghut',
    'ar-tafsir-al-tabari'
)
# Out:
# file found for Tgy
# loading data/roots/T?gy.tsv
# Successfully loaded data from 'dat/roots/T?gy.tsv'
# file found for firoEawn
# loading data/roots/firoE?awn.tsv
# Successfully loaded data from 'dat/roots/firoE?awn.tsv'
# file found for firoEawn
# loading data/roots/firoE?awn.tsv
# Successfully loaded data from 'dat/roots/firoE?awn.tsv'
# file found for Tgy
# loading data/roots/T?gy.tsv
# Successfully loaded data from 'dat/roots/T?gy.tsv'
# file found for TaAguwt
# loading data/roots/T?aA?guwt.tsv
# Successfully loaded data from 'dat/roots/T?aA?guwt.tsv'
#
# total 124 instances found
# 'sorter.json' found'
# last item in sorter: 110:3
# successfully loaded sorter of length 6236 from 'sorter.json'
#
# repDic before checking md:  {'96:6': {'string': '\n[Q.96:6](https://quran.com/96:6/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#96:6]]\n', 'queries': [{'query': 'Tgy ()', 'postquery': ''}]}, '73:15': {'string': '\n[Q.73:15](https://quran.com/73:15/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#73:15]]\n', 'queries': [{'query': 'firoEawn ()', 'postquery': ''}]}, '73:16': {'string': '\n[Q.73:16](https://quran.com/73:16/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#73:16]]\n', 'queries': [{'query': 'firoEawn ()', 'postquery': ''}]}, '89:10': {'string': '\n[Q.89:10](https://quran.com/89:10/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#89:10]]\n', 'queries': [{'query': 'firoEawn ()', 'postquery': ''}]}, '89:11': {'string': '\n[Q.89:11](https://quran.com/89:11/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#89:11]]\n', 'queries': [{'query': 'Tgy ()', 'postquery': ''}]}, '53:17': {'string': '\n[Q.53:17](https://quran.com/53:17/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#53:17]]\n', 'queries': [{'query': 'Tgy ()', 'postquery': ''}]}, '53:52': {'string': '\n[Q.53:52](https://quran.com/53:52/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#53:52]]\n', 'queries': [{'query': 'Tgy ()', 'postquery': ''}]}, '91:11': {'string': '\n[Q.91:11](https://quran.com/91:11/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#91:11]]\n', 'queries': [{'query': 'Tgy ()', 'postquery': ''}]}, '85:18': {'string': '\n[Q.85:18](https://quran.com/85:18/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#85:18]]\n', 'queries': [{'query': 'firoEawn ()', 'postquery': ''}]}, '50:13': {'string': '\n[Q.50:13](https://quran.com/50:13/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#50:13]]\n', 'queries': [{'query': 'firoEawn ()', 'postquery': ''}]}, '50:27': {'string': '\n[Q.50:27](https://quran.com/50:27/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#50:27]]\n', 'queries': [{'query': 'Tgy ()', 'postquery': ''}]}, '54:41': {'string': '\n[Q.54:41](https://quran.com/54:41/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#54:41]]\n', 'queries': [{'query': 'firoEawn ()', 'postquery': ''}]}, '38:12': {'string': '\n[Q.38:12](https://quran.com/38:12/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#38:12]]\n', 'queries': [{'query': 'firoEawn ()', 'postquery': ''}]}, '38:55': {'string': '\n[Q.38:55](https://quran.com/38:55/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsed#38:55]]\n', 'queries': [{'query': 'Tgy ()', 'postquery': ''}]},