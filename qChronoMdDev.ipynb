# %%
'a' not in []
# Out:
# True

# %%
flnm = 'firawn_taghut'

mdFile = f'data/compare/{flnm}.md'

import re

with open(mdFile) as f:
    strn = f.read()

rep = re.compile(
        '\n#\s*(?:Q\:){0,1}(\d{1,}\:\d{1,})(.*?(?=\n#|$))(?:(\n##\s{1,}.*?(?=\n#\s{1,}|$))){0,1}',
        re.DOTALL
    ).findall(

    strn
)


print(len(rep))

repDic = { 
    setty[0]: { 
        'string' : setty[1] , 
        'queries': [
            {
                'query': quer[0],
                'postquery': quer[1],
            
            }
            # quer
            for quer in re.compile(
                '\n##\s{1,}([^\n]{1,}(?=\n))(.*?(?=\n))',    
                re.DOTALL,
            ).findall(
                setty[2] 
            )
        ]
            if len(setty) > 2 else None 
    }
    for setty in rep 
}

print(repDic)

# %%
import re

with open("/mnt/f/Documents/notes/Ref/iamb.mystery3.md") as f:
    strn1 = f.read()

matches1 = re.compile(
    # '[#]{1,}\s*[c]{0,1}\d{1,}(?:\.{0,1})\d{0,}\n'
    # 'subtype="sec'
    # '\n#{1,2}\s*[c]{0,1}(\d{1,})\.{0,1}(\d{0,})\n(.*?(?=\n#|$))',
    '\n#{1,2}\s*(\d{1,})\.(\d{1,})(.*?(?=\n#|$))',
    re.DOTALL
).findall(
    strn1
)


with open("/mnt/f/Documents/notes/Ref/iamb.myst/096.html") as f:
    strn2 = f.read()

matches2 = re.compile(
    # '[#]{1,}\s*[c]{0,1}\d{1,}(?:\.{0,1})\d{0,}\n'
    # 'subtype="sec'
    # '\n#{1,2}\s*[c]{0,1}(\d{1,})\.{0,1}(\d{0,})\n(.*?(?=\n#|$))',
    'CHAP\.\s[0IVX]*(.*?)(?=CHAP\.\s|$)',
    re.DOTALL
).findall(
    strn2
)

# n = 94
print(
    len(matches1),
    len(matches2)
    #   +n
      )

# matches1
strNew = ''
for n in range(len(matches1)):
    # if n == len(matches1)-1:
        # print(
        #     matches1[n],
        #     matches2[n]
        #     )
    strNew += f'\n\n## {matches1[n][0]}.{matches1[n][1]}\n{matches1[n][2]}\n{matches2[n]}'

# print(strNew)
with open('/mnt/f/Documents/notes/Ref/iamb.myst4.md', 'w') as f:
    f.write(strNew)
# Out:
# 141 141

# %%
import re

with open('/mnt/f/Documents/notes/Ref/iamb.MEg.md') as f:
    strn1 = f.read()

matches = re.compile(
    '\n##\s\d*\.\d*'
).findall(
    strn1
)

len(matches)
# Out:
# 141

# %%
import re

with open("/mnt/f/Documents/notes/Ref/iamb.MEg.md") as f:
    strn1 = f.read()

matches = re.compile(
    '(\n##\s\d*\.\d*\n)([^#a-zA-Z]*?(?=[a-zA-Z]))([^#]*(?=\n#|$))',
    re.DOTALL
).findall(
    strn1
)

print(
    # matches
    len(matches)
)

strnNew = ''

for match in matches:
    strnNew += match[0]
    secs = re.compile(
        # '[#]{1,}\s*[c]{0,1}\d{1,}(?:\.{0,1})\d{0,}\n'
        # 'subtype="sec'
        # '\n#{1,2}\s*[c]{0,1}(\d{1,})\.{0,1}(\d{0,})\n(.*?(?=\n#|$))',
        '([^#\.0-9a-zA-Z]{1,}\.)',
        re.DOTALL
    ).findall(
        match[1]
    )

    # print(secs)

    matchUpd = ''
    for n in range(len(secs)):
        secu = secs[n].strip('\n').strip(' ')
        matchUpd += f'\n\n### {n+1}\n\n#### gr\n\n{secu}\n\n#### en\n\n#### sn\n\n{secu}\n\n#### ar\n\n{secu}\n\n'
    
    # print('--------------------', matchUpd)

    strnNew += matchUpd

    strnNew += match[2]
# ).sub(
#     '### \n#### gr\\1\n\n#### en \n\n#### sn\n\n\\1\n\n#### ar\n\n\\1',
#     strn1
# )

# matches1
# strn1
with open('/mnt/f/Documents/notes/Ref/iamb.MEg2.md', 'w') as f:
    f.write(strnNew)
# Out:
# 139

# %%
# from qChronolyze import filtDown, getSorter
from qChronolyze import aggregLsts, getSorter

def qChronoMd(dicti,flnm,tafs):
    mdFile = f'data/compare/{flnm}.md'
    # instLstAgg = []
    queriesLeft = { f'{list(item.keys())[0]} ({list(item.values())[0]})' for item in dicti }
    alreadyRefed = []
    instLstAgg = aggregLsts(dicti,tafs)

    import pandas as pd

    df = pd.DataFrame(instLstAgg)
    sorter = getSorter()
    df['surah:ayah'] = pd.Categorical(df['surah:ayah'], categories=sorter, ordered=True)
    df.sort_values(["surah:ayah","position"],inplace=True)
    # df.reset_index(drop=True,inplace=True)
    sortedRecs = df.to_dict(orient='records')


    repDic = {}

    for rec in sortedRecs:
        if rec["surah:ayah"] not in repDic.keys():
            repDic[rec["surah:ayah"]] = {
                'string': f'\n[Q.{rec["surah:ayah"]}](https://quran.com/{rec["surah:ayah"]}/tafsirs/{tafs})\n'
                            + f'\n![[Qrsed#{rec["surah:ayah"]}]]\n',
                # 'queries': [
                #     {
                #         'query': rec["query"],
                #         'postquery': ''
                #     }
                # ]
                'queries': {
                    rec["query"]: ''
                }
            }
        else:
            # repDic[rec["surah:ayah"]]["queries"].append(
            #     {
            #         'query': rec["query"], 
            #         'postquery': '',
            #     }
            # )
            repDic[rec["surah:ayah"]]["queries"][rec["query"]] = ''



    # print('\nrepDic before checking md: ', repDic, '\n')

    import re

    with open(mdFile) as f:
        strn = f.read()

    rep = re.compile(
            '\n#\s*(?:Q\:){0,1}(\d{1,}\:\d{1,})(.*?(?=\n#|$))(?:(\n##\s{1,}.*?(?=\n#\s{1,}|$))){0,1}',
            re.DOTALL
        ).findall(

        strn
    )


    # print(len(rep))

    for setty in rep:
        if setty[0] not in repDic:
            repDic[setty[0]] = { 
                'string' : setty[1] , 
                'queries': {
                     quer[0]: quer[1]
                    
                    
                    # quer
                    for quer in re.compile(
                        '\n##\s{1,}([^\n]{1,}(?=\n))(.*?(?=\n))',    
                        re.DOTALL,
                    ).findall(
                        setty[2] 
                    )
                }
                    if len(setty) > 2 else {}
                # 'queries': [
                #     {
                #         'query': quer[0],
                #         'postquery': quer[1],
                    
                #     }
                #     # quer
                #     for quer in re.compile(
                #         '\n##\s{1,}([^\n]{1,}(?=\n))(.*?(?=\n))',    
                #         re.DOTALL,
                #     ).findall(
                #         setty[2] 
                #     )
                # ]
                #     if len(setty) > 2 else None 
            }
        else:
           print(f'\nVerse string before: {repDic[setty[0]]}')
           for quer in re.compile(
                        '\n##\s{1,}([^\n]{1,}(?=\n))(.*?(?=\n))',    
                        re.DOTALL,
                    ).findall(
                        setty[2] 
                    ):
                repDic[setty[0]]['string'] = setty[1]
                repDic[setty[0]]['queries'][quer[0]] = quer[1]
                # repDic[setty[0]]['queries'].append({
                #         'query': quer[0],
                #         'postquery': quer[1],
                    
                #     })
                
           print(f'\nVerse string after: {repDic[setty[0]]}')
        

    # print('\nrepDic after checking md: ', repDic, '\n')
    # print(repDic)

    sorterIdxs = [sorter.index(suray) for suray in repDic.keys()]

    surAyOrdered = [sorter[idx] for idx in sorterIdxs]
    
    newStr = ''

    for surAy in surAyOrdered:       
        newStrUp =   f'\n# Q:{surAy}\n' + f'\n[Q.{surAy}](https://quran.com/{surAy}/tafsirs/{tafs})\n' + f'\n![[Qrsed#{surAy}]]\n'

        newStr += newStrUp

        alreadyRefed.append(rec["surah:ayah"])
        # for query in repDic[surAy]['queries']:
        #     if query['query'] in queriesLeft:
        #         print(f'\nquery left at {surAy} : {query["query"]}')
        #         newStrUp = f'\n## {query["query"]}\n' + query['postquery']
        #         newStr += newStrUp
        #         queriesLeft.remove(query["query"])
        for q, pq in repDic[surAy]['queries'].items():
            if q in queriesLeft:
                print(f'\nquery left at {surAy} : {q}')
                newStrUp = f'\n## {q}\n' + pq
                newStr += newStrUp
                queriesLeft.remove(q)

    with open(mdFile, 'w') as f:
        f.write(newStr)

# %% [markdown]
# # try

# %%
from qChronoMd import querizeMd
qL =    [
    [
        {
            "strL": [
                {
                    "stri": 'Tgy',
                },
                
            ]
        },
        {
            "strL": [
                {
                    "stri": 'TaAguwt',
                },
                 
            ]
        },
    ],
    [
        {
            "strL": [
                {
                    "stri": 'firoEawn',
                },
                
            ]
        },
    ],
    [
        {
            "strL": [
                {
                    "stri": 'firoEawn',
                },
                {
                    "stri": 'TaAguwt',
                },                                
                 
                
            ]
        },
    ],
    [
        {
            "strL": [
                {
                    "stri": 'firoEawn',
                },
                {
                    "stri": 'Tgy',
                },
                 
                
            ]
        },
    ]
]

querizeMd(
    qL=qL,
    flnm='firawn_taghut',
    refLng='arabic'
)
# Out:
# not interactive
# strLSt in comb init: []
# strL in comb init: [{'stri': 'Tgy'}]
# args in str init:  Tgy  All All All arabic buckwalter_Scheme
# props set in str init:  Tgy  All All All arabic buckwalter_Scheme
# Tgy  All All All arabic buckwalter_Scheme
# strL in comb after str obj: [<qChronolyze.strObjClass object at 0x7f116d5108e0>]
# strLSt in comb init: []
# strL in comb init: [{'stri': 'TaAguwt'}]
# args in str init:  TaAguwt  All All All arabic buckwalter_Scheme
# props set in str init:  TaAguwt  All All All arabic buckwalter_Scheme
# TaAguwt  All All All arabic buckwalter_Scheme
# strL in comb after str obj: [<qChronolyze.strObjClass object at 0x7f116d5107f0>]
# strLSt in comb init: []
# strL in comb init: [{'stri': 'firoEawn'}]
# args in str init:  firoEawn  All All All arabic buckwalter_Scheme
# props set in str init:  firoEawn  All All All arabic buckwalter_Scheme
# firoEawn  All All All arabic buckwalter_Scheme
# strL in comb after str obj: [<qChronolyze.strObjClass object at 0x7f116d5105e0>]
# strLSt in comb init: []
# strL in comb init: [{'stri': 'firoEawn'}, {'stri': 'TaAguwt'}]
# args in str init:  firoEawn  All All All arabic buckwalter_Scheme
# props set in str init:  firoEawn  All All All arabic buckwalter_Scheme
# firoEawn  All All All arabic buckwalter_Scheme
# args in str init:  TaAguwt  All All All arabic buckwalter_Scheme
# props set in str init:  TaAguwt  All All All arabic buckwalter_Scheme
# TaAguwt  All All All arabic buckwalter_Scheme
# strL in comb after str obj: [<qChronolyze.strObjClass object at 0x7f116d5107c0>, <qChronolyze.strObjClass object at 0x7f116d51ac40>]
# strLSt in comb init: []
# strL in comb init: [{'stri': 'firoEawn'}, {'stri': 'Tgy'}]
# args in str init:  firoEawn  All All All arabic buckwalter_Scheme
# props set in str init:  firoEawn  All All All arabic buckwalter_Scheme
# firoEawn  All All All arabic buckwalter_Scheme
# args in str init:  Tgy  All All All arabic buckwalter_Scheme
# props set in str init:  Tgy  All All All arabic buckwalter_Scheme
# Tgy  All All All arabic buckwalter_Scheme
# strL in comb after str obj: [<qChronolyze.strObjClass object at 0x7f116d51acd0>, <qChronolyze.strObjClass object at 0x7f116d51a6a0>]
# [<qChronolyze.combClass object at 0x7f116d50b6a0>, <qChronolyze.combClass object at 0x7f117ec64a30>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f116d50b6a0>
# optStInsts after comb: []
# strL: [<qChronolyze.strObjClass object at 0x7f116d5108e0>]
# for string: Tgy
# file found for Tgy
# Successfully loaded data from 'data/cache/arb/طغي/All/All/All.tsv: lenght 39'
# <qChronolyze.combClass object at 0x7f117ec64a30>
# optStInsts after comb: [<qChronolyze.row2DictCl object at 0x7f116d51abb0>, <qChronolyze.row2DictCl object at 0x7f116d51ae20>, <qChronolyze.row2DictCl object at 0x7f116d51af10>, <qChronolyze.row2DictCl object at 0x7f116d51a4f0>, <qChronolyze.row2DictCl object at 0x7f116d51af70>, <qChronolyze.row2DictCl object at 0x7f116d51ab20>, <qChronolyze.row2DictCl object at 0x7f116d51ad90>, <qChronolyze.row2DictCl object at 0x7f116d51ad60>, <qChronolyze.row2DictCl object at 0x7f116d51a910>, <qChronolyze.row2DictCl object at 0x7f116d51aa90>, <qChronolyze.row2DictCl object at 0x7f116d51adf0>, <qChronolyze.row2DictCl object at 0x7f116d3ebee0>, <qChronolyze.row2DictCl object at 0x7f116d3ebf70>, <qChronolyze.row2DictCl object at 0x7f116d3ebdc0>, <qChronolyze.row2DictCl object at 0x7f116d3ebfa0>, <qChronolyze.row2DictCl object at 0x7f116d3ebfd0>, <qChronolyze.row2DictCl object at 0x7f116d3ebd90>, <qChronolyze.row2DictCl object at 0x7f116d3ebe50>, <qChronolyze.row2DictCl object at 0x7f116d3ebf10>, <qChronolyze.row2DictCl object at 0x7f116d3ebf40>, <qChronolyze.row2DictCl object at 0x7f116d3ebe80>, <qChronolyze.row2DictCl object at 0x7f116d3ebdf0>, <qChronolyze.row2DictCl object at 0x7f116d3ebeb0>, <qChronolyze.row2DictCl object at 0x7f116d3aefd0>, <qChronolyze.row2DictCl object at 0x7f116d3ae400>, <qChronolyze.row2DictCl object at 0x7f116d3aedf0>, <qChronolyze.row2DictCl object at 0x7f116d3aeb20>, <qChronolyze.row2DictCl object at 0x7f116d3ae100>, <qChronolyze.row2DictCl object at 0x7f116d3ae4c0>, <qChronolyze.row2DictCl object at 0x7f116d3ae520>, <qChronolyze.row2DictCl object at 0x7f116d3ae3a0>, <qChronolyze.row2DictCl object at 0x7f116d3ae040>, <qChronolyze.row2DictCl object at 0x7f116d3ae1c0>, <qChronolyze.row2DictCl object at 0x7f116d3ae490>, <qChronolyze.row2DictCl object at 0x7f116dd9f670>, <qChronolyze.row2DictCl object at 0x7f116d3a00d0>, <qChronolyze.row2DictCl object at 0x7f116d3a0fa0>, <qChronolyze.row2DictCl object at 0x7f116d3a0fd0>, <qChronolyze.row2DictCl object at 0x7f116d3a0f70>]
# strL: [<qChronolyze.strObjClass object at 0x7f116d5107f0>]
# for string: TaAguwt
# file found for TaAguwt
# Successfully loaded data from 'data/cache/arb/طَاغُوت/All/All/All.tsv: lenght 8'
# [<qChronolyze.combClass object at 0x7f116d5109d0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f116d5109d0>
# optStInsts after comb: []
# strL: [<qChronolyze.strObjClass object at 0x7f116d5105e0>]
# for string: firoEawn
# file found for firoEawn
# Successfully loaded data from 'data/cache/arb/فِرْعَون/All/All/All.tsv: lenght 74'
# [<qChronolyze.combClass object at 0x7f116d5100a0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f116d5100a0>
# optStInsts after comb: []
# strL: [<qChronolyze.strObjClass object at 0x7f116d5107c0>, <qChronolyze.strObjClass object at 0x7f116d51ac40>]
# for string: firoEawn
# file found for firoEawn
# Successfully loaded data from 'data/cache/arb/فِرْعَون/All/All/All.tsv: lenght 74'
# for string: TaAguwt
# file found for TaAguwt
# Successfully loaded data from 'data/cache/arb/طَاغُوت/All/All/All.tsv: lenght 8'
# [<qChronolyze.combClass object at 0x7f116d510880>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f116d510880>
# optStInsts after comb: []
# strL: [<qChronolyze.strObjClass object at 0x7f116d51acd0>, <qChronolyze.strObjClass object at 0x7f116d51a6a0>]
# for string: firoEawn
# file found for firoEawn
# Successfully loaded data from 'data/cache/arb/فِرْعَون/All/All/All.tsv: lenght 74'
# for string: Tgy
# file found for Tgy
# Successfully loaded data from 'data/cache/arb/طغي/All/All/All.tsv: lenght 39'
#
# total 117 instances found
# 'sorter.json' found'
# last item in sorter: 110:3
# successfully loaded sorter of length 6236 from 'sorter.json'
#
# Number of ayahs: 103
#
# query left at 96:6 : Tgy () / TaAguwt ()
#
# query left at 96:6 : Tgy ()
#
# query left at 73:15 : firoEawn ()
#
# query left at 20:24 : firoEawn () + Tgy ()
#
# query left at 20:24 : firoEawn Tgy ( )
#
# query left at 39:17 : TaAguwt ()

# %%
import re
re.findall(
    "\n*",
    ""
)
# Out:
# ['']

# %%
# from aggregates_test import *
from aggregates import *

from qChronoMd import qChronoMd

qChronoMd(
    [
        *shirk
    ],
    flnm='shirk3',
    refLng='arabic'
)
# Out:
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  wad~ flt: wadd strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wad~ flt: wadd strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  wdd flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wdd flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  {ll~a`t flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  {ll~a`t flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  lwt flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  lwt flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  {ll~a`t flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  {ll~a`t flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  lwy flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  lwy flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  {ll~a`t flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  {ll~a`t flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  lyt flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  lyt flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  {loEuz~aY` flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  {loEuz~aY` flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ezz flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ezz flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  {loEuz~aY` flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  {loEuz~aY` flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ezw flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ezw flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  manaw`p flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  manaw`p flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  mny flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  mny flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  baEol2 flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  baEol2 flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  bEl flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  bEl flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  ma`lik2 flt: malik strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  ma`lik2 flt: malik strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  mlk flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  mlk flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  suwaAE flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  suwaAE flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  swE flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  swE flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  yaguwv flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  yaguwv flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  gyv flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  gyv flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  yaguwv flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  yaguwv flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  gwv flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  gwv flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  yaEuwq flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  yaEuwq flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ewq flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ewq flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  nasor flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nasor flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  T~a`guwt flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  T~a`guwt flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Tgy flt:  strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Tgy flt:  strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  wvn flt: idol strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wvn flt: idol strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Snm flt: idol strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Snm flt: idol strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  nuSub flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nuSub flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  naSiyb flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  naSiyb flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  nuSub flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nuSub flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  nuSob flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nuSob flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  nuSub flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nuSub flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  naSiyb flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  naSiyb flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  nuSub flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nuSub flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  naSab flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  naSab flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  nuSub flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nuSub flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  n~aASibap flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  n~aASibap flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  nuSub flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nuSub flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  nSb flt:  strTyp: root frm: None poSp: V inpLng: None inpSch: None
# props set in str init:  stri:  nSb flt:  strTyp: root frm: All poSp: V inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  naSiyb flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  naSiyb flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  jEl flt: assign strTyp: root frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jEl flt: assign strTyp: root frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  saA^}ibap flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  saA^}ibap flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  waSiylap flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  waSiylap flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  wSl flt:  strTyp: root frm: i poSp: V inpLng: None inpSch: None
# props set in str init:  stri:  wSl flt:  strTyp: root frm: i poSp: V inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  waSiylap flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  waSiylap flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  wSl flt:  strTyp: root frm: ii poSp: V inpLng: None inpSch: None
# props set in str init:  stri:  wSl flt:  strTyp: root frm: ii poSp: V inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  baHor flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  baHor flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  baHiyrap flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  baHiyrap flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  HaAm flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  HaAm flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Hamiy~ap flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Hamiy~ap flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  HaAm flt:  strTyp: stem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  HaAm flt:  strTyp: stem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Hmy flt:  strTyp: root frm: None poSp: V inpLng: None inpSch: None
# props set in str init:  stri:  Hmy flt:  strTyp: root frm: All poSp: V inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  >azolaAm flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  >azolaAm flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Hrm flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Hrm flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Anv flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Anv flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  xlS flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  xlS flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  bTn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  bTn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  *kr flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  *kr flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $Er flt: [Pp]oet(?!r) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Er flt: [Pp]oet(?!r) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $Er flt: (?:[Pp]oetry) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Er flt: (?:[Pp]oetry) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  ma$oEar flt:  strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  ma$oEar flt:  strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  $Er flt: (?:[Hh]air) strTyp: root frm: i poSp: V inpLng: None inpSch: None
# props set in str init:  stri:  $Er flt: (?:[Hh]air) strTyp: root frm: i poSp: V inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $aAEir flt: (?:[Ss]ymbol|rite) strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $aAEir flt: (?:[Ss]ymbol|rite) strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $iEor flt: (?:[Mm]onument) strTyp: lem frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $iEor flt: (?:[Mm]onument) strTyp: lem frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $Er flt: [Ss]irius strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Er flt: [Ss]irius strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $Tn flt: (?:devil|[^d]evil|demon|shaitaan) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Tn flt: (?:devil|[^d]evil|demon|shaitaan) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  <iboliys flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  <iboliys flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  bls flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  bls flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ flt: (?:[jJ]inn) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ flt: (?:[jJ]inn) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jin~ap flt: (?:[Jj]inn|mad) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jin~ap flt: (?:[Jj]inn|mad) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt: (?:^mad$|mad man|madman|surely mad) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt: (?:^mad$|mad man|madman|surely mad) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jaAn~ flt: (?:snake|jinn) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jaAn~ flt: (?:snake|jinn) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Hyy flt: snake strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Hyy flt: snake strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  qrn flt: companion strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  qrn flt: companion strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $Tn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Tn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  qrn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  qrn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt: jinn strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt: jinn strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  $Tn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Tn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  mrd flt: rebellious strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  mrd flt: rebellious strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Eiforiyt flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Eiforiyt flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $Tn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Tn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  mss flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  mss flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnd flt: (?:host|troop|force) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jnd flt: (?:host|troop|force) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  <iboliys flt: (?:iblis|devil|satan) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  <iboliys flt: (?:iblis|devil|satan) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $Tn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Tn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  wly flt: (?:ally|allies|guardian|protector|friend) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wly flt: (?:ally|allies|guardian|protector|friend) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $Tn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Tn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ebd flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ebd flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  laA flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  laA flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $Tn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Tn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Anv flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Anv flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  dEw flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  dEw flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $Tn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $Tn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  qrn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  qrn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt: (?:jinn) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt: (?:jinn) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  dwn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  dwn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ebd flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ebd flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jnn flt: (?:jinn) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jnn flt: (?:jinn) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  $rk flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $rk flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Alh flt: (?:^((?!Allah).)*$) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Alh flt: (?:^((?!Allah).)*$) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  dwn flt: (?:other|esides|exclud|Us|instead) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  dwn flt: (?:other|esides|exclud|Us|instead) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Alh flt: (?:^((?!Allah).)*$) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Alh flt: (?:^((?!Allah).)*$) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Axr flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Axr flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  maEa flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  maEa flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Ebd flt: (?:worship|serv) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ebd flt: (?:worship|serv) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  dwn flt: (?:other|esides|exclud|Us|instead) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  dwn flt: (?:other|esides|exclud|Us|instead) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  dEw flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  dEw flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  maEa flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  maEa flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  AHd flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  AHd flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  dEw flt: (?:^((?!caller).)*$) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  dEw flt: (?:^((?!caller).)*$) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  dwn flt: (?:other|esides|exclud|Us|instead) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  dwn flt: (?:other|esides|exclud|Us|instead) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Ax* flt:  strTyp: root frm: viii poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ax* flt:  strTyp: root frm: viii poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Alh flt: (?:^((?!Allah).)*$) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Alh flt: (?:^((?!Allah).)*$) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Ax* flt:  strTyp: root frm: viii poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ax* flt:  strTyp: root frm: viii poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  dwn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  dwn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Ax* flt: (?:^((?!we).)*$) strTyp: root frm: viii poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ax* flt: (?:^((?!we).)*$) strTyp: root frm: viii poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  wld flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wld flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  wld flt: (?:begot|beget) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wld flt: (?:begot|beget) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Alh flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Alh flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  wld flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wld flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  sbH flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  sbH flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  lam flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  lam flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  wld flt: (?:begot|beget) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wld flt: (?:begot|beget) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Ax* flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ax* flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  SHb flt: (?:wife) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  SHb flt: (?:wife) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  <an~aY flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  <an~aY flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  wld flt: (?:son) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  wld flt: (?:son) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  <an~aY flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  <an~aY flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  SaAHibap flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  SaAHibap flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Ax* flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ax* flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Anv flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Anv flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  malak flt: (?:[Aa]ngel) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  malak flt: (?:[Aa]ngel) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Anv flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Anv flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Ax* flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ax* flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  bny flt: (?:[Dd]aughter) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  bny flt: (?:[Dd]aughter) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jEl flt: assign strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jEl flt: assign strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  bny flt: (?:[Dd]aughter) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  bny flt: (?:[Dd]aughter) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  xrq flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  xrq flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  bny flt: (?:[Ss]on|[Ss]hild|[Dd]aughter) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  bny flt: (?:[Ss]on|[Ss]hild|[Dd]aughter) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $ariyk flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $ariyk flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  sjd flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  sjd flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  A^dam flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  A^dam flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  malak flt: (?:[Aa]ngel) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  malak flt: (?:[Aa]ngel) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  kwkb flt: star strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  kwkb flt: star strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  rAy flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  rAy flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  kwkb flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  kwkb flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  rab~ flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  rab~ flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  ha`*aA flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  ha`*aA flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  njm flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  njm flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  nZr flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nZr flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $ms flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $ms flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  rab~ flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  rab~ flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  ha`*aA flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  ha`*aA flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $ms flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $ms flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  sjd flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  sjd flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  dwn flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  dwn flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  $ms flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  $ms flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  sjd flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  sjd flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  laA flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  laA flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ebd flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ebd flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  qmr flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  qmr flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  rab~ flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  rab~ flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  ha`*aA flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  ha`*aA flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  rhb flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  rhb flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  rbb flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  rbb flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ax* flt: (?:taken) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ax* flt: (?:taken) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  Hbr flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Hbr flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  rbb flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  rbb flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ax* flt: (?:taken) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ax* flt: (?:taken) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  mlk flt: (?:[Aa]ngel) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  mlk flt: (?:[Aa]ngel) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ax* flt:  strTyp: root frm: viii poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ax* flt:  strTyp: root frm: viii poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  rbb flt: (?:[Ll]ords) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  rbb flt: (?:[Ll]ords) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  nbA flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  nbA flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ax* flt:  strTyp: root frm: viii poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ax* flt:  strTyp: root frm: viii poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  rbb flt: (?:[Ll]ords) strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  rbb flt: (?:[Ll]ords) strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# qyArLegSch is  arabic_Scheme
# args in str init:  stri:  jzA flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  jzA flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# args in str init:  stri:  Ebd flt:  strTyp: None frm: None poSp: None inpLng: None inpSch: None
# props set in str init:  stri:  Ebd flt:  strTyp: All frm: All poSp: All inpLng: arabic inpSch: buckwalter_Scheme
# [<qChronolyze.combClass object at 0x7f0920a40370>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0920a40370>
# optStInsts after comb: []
# wad~ lem All wadd All False arb bkwSch
# wdd root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f09209dfac0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f09209dfac0>
# optStInsts after comb: []
# {ll~a`t lem All  All False arb bkwSch
# lwt root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cb1070>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cb1070>
# optStInsts after comb: []
# {ll~a`t lem All  All False arb bkwSch
# lwy root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cb1520>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cb1520>
# optStInsts after comb: []
# {ll~a`t lem All  All False arb bkwSch
# lyt root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cb1100>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cb1100>
# optStInsts after comb: []
# {loEuz~aY` lem All  All False arb bkwSch
# Ezz root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cb11c0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cb11c0>
# optStInsts after comb: []
# {loEuz~aY` lem All  All False arb bkwSch
# Ezw root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cb1280>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cb1280>
# optStInsts after comb: []
# manaw`p lem All  All False arb bkwSch
# mny root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cb1430>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cb1430>
# optStInsts after comb: []
# baEol2 lem All  All False arb bkwSch
# bEl root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cb1370>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cb1370>
# optStInsts after comb: []
# ma`lik2 lem All malik All False arb bkwSch
# mlk root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cb12b0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cb12b0>
# optStInsts after comb: []
# suwaAE lem All  All False arb bkwSch
# swE root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbe940>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbe940>
# optStInsts after comb: []
# yaguwv lem All  All False arb bkwSch
# gyv root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbe7f0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbe7f0>
# optStInsts after comb: []
# yaguwv lem All  All False arb bkwSch
# gwv root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbe700>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbe700>
# optStInsts after comb: []
# yaEuwq lem All  All False arb bkwSch
# Ewq root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbe580>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbe580>
# optStInsts after comb: []
# nasor lem All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbe5b0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbe5b0>
# optStInsts after comb: []
# T~a`guwt lem All  All False arb bkwSch
# Tgy root All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbe4f0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbe4f0>
# optStInsts after comb: []
# wvn All All idol All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbe3a0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbe3a0>
# optStInsts after comb: []
# Snm All All idol All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbe820>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbe820>
# optStInsts after comb: []
# nuSub stem All  All False arb bkwSch
# naSiyb stem All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbeee0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbeee0>
# optStInsts after comb: []
# nuSub stem All  All False arb bkwSch
# nuSob stem All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbefd0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbefd0>
# optStInsts after comb: []
# nuSub stem All  All False arb bkwSch
# naSiyb stem All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbee50>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbee50>
# optStInsts after comb: []
# nuSub stem All  All False arb bkwSch
# naSab stem All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbedc0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbedc0>
# optStInsts after comb: []
# nuSub stem All  All False arb bkwSch
# n~aASibap stem All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbed60>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbed60>
# optStInsts after comb: []
# nuSub stem All  All False arb bkwSch
# nSb root All  V False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbebb0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbebb0>
# optStInsts after comb: []
# naSiyb stem All  All False arb bkwSch
# jEl root All assign All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbeca0>]
# optStInsts before comb: []
# <qChronolyze.combClass object at 0x7f0999cbeca0>
# optStInsts after comb: []
# saA^}ibap All All  All False arb bkwSch
# [<qChronolyze.combClass object at 0x7f0999cbea90>]
# optStInsts before comb: []
# ...
#
# Verse string after reading: {'string': '\n\n[Q.20:20](https://quran.com/20:20/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#20:20]]\n', 'queries': {'حيي (snake)': '\n\n', 'Hyy (snake)': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.26:95](https://quran.com/26:95/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#26:95]]\n', 'queries': {'إِبْلِيس': '\n\n', 'جند إِبْلِيس ((?:host|troop|force) (?:iblis|devil|satan))': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.26:95](https://quran.com/26:95/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#26:95]]\n', 'queries': {'إِبْلِيس': '\n\n', 'جند إِبْلِيس ((?:host|troop|force) (?:iblis|devil|satan))': '\n\n', 'jnd <iboliys ((?:host|troop|force) (?:iblis|devil|satan))': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.27:24](https://quran.com/27:24/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#27:24]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n', 'شمس سجد دون': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.27:24](https://quran.com/27:24/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#27:24]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n', 'شمس سجد دون': '\n\n', '$ms sjd dwn (  )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.27:39](https://quran.com/27:39/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#27:39]]\n', 'queries': {'جِنّ ((?:[jJ]inn))': '\n\n', 'عِفْرِيت': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.27:39](https://quran.com/27:39/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#27:39]]\n', 'queries': {'جِنّ ((?:[jJ]inn))': '\n\n', 'عِفْرِيت': '\n\n', 'Eiforiyt ()': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.17:40](https://quran.com/17:40/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#17:40]]\n', 'queries': {'اخذ انث': '\n\n', 'مَلَك انث ((?:[Aa]ngel) )': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.17:40](https://quran.com/17:40/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#17:40]]\n', 'queries': {'اخذ انث': '\n\n', 'مَلَك انث ((?:[Aa]ngel) )': '\n\n', 'Ax* Anv ( )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.12:4](https://quran.com/12:4/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#12:4]]\n', 'queries': {'كوكب راي (star )': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.12:4](https://quran.com/12:4/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#12:4]]\n', 'queries': {'كوكب راي (star )': '\n\n', 'kwkb ()': '## kwkb rAy (star )'}}
#
# Verse string before reading: {'string': '\n\n[Q.6:44](https://quran.com/6:44/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:44]]\n', 'queries': {'بلس': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.6:44](https://quran.com/6:44/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:44]]\n', 'queries': {'بلس': '\n\n', 'bls ()': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.6:76](https://quran.com/6:76/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:76]]\n', 'queries': {'كوكب راي (star )': '\n\n', 'كوكب رَبّ هَٰذَا': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.6:76](https://quran.com/6:76/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:76]]\n', 'queries': {'كوكب راي (star )': '\n\n', 'كوكب رَبّ هَٰذَا': '\n\n', 'kwkb rab~ ha`*aA (  )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.6:77](https://quran.com/6:77/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:77]]\n', 'queries': {'قمر رَبّ هَٰذَا': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.6:77](https://quran.com/6:77/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:77]]\n', 'queries': {'قمر رَبّ هَٰذَا': '\n\n', 'qmr rab~ ha`*aA (  )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.6:78](https://quran.com/6:78/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:78]]\n', 'queries': {'شمس رَبّ هَٰذَا': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.6:78](https://quran.com/6:78/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:78]]\n', 'queries': {'شمس رَبّ هَٰذَا': '\n\n', '$ms rab~ ha`*aA (  )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.6:100](https://quran.com/6:100/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:100]]\n', 'queries': {'جِنّ ((?:[jJ]inn))': '\n\n', 'جنن شرك ((?:jinn) )': '\n\n', 'خرق بني ( (?:[Ss]on|[Ss]hild|[Dd]aughter))': '\n\n', 'شَرِيك': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.6:100](https://quran.com/6:100/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:100]]\n', 'queries': {'جِنّ ((?:[jJ]inn))': '\n\n', 'جنن شرك ((?:jinn) )': '\n\n', 'خرق بني ( (?:[Ss]on|[Ss]hild|[Dd]aughter))': '\n\n', 'شَرِيك': '\n\n', 'jnn $rk ((?:jinn) )': '## xrq bny ( (?:[Ss]on|[Ss]hild|[Dd]aughter))'}}
# for 6:101 secondaries:  [('<an~aY wld ( (?:son))', '', '## <an~aY SaAHibap (  )')]
#
# old not in new 3: 6:101
#
# Verse string before reading: {'string': '\n\n[Q.6:112](https://quran.com/6:112/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:112]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n', 'جِنّ ((?:[jJ]inn))': '\n\n', 'جنن شطن (jinn )': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.6:112](https://quran.com/6:112/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:112]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n', 'جِنّ ((?:[jJ]inn))': '\n\n', 'جنن شطن (jinn )': '\n\n', 'jnn $Tn (jinn )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.6:136](https://quran.com/6:136/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:136]]\n', 'queries': {'نَصِيب جعل ( assign)': '\n\n', 'شَرِيك': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.6:136](https://quran.com/6:136/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:136]]\n', 'queries': {'نَصِيب جعل ( assign)': '\n\n', 'شَرِيك': '\n\n', 'jEl nSb (assign )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.6:139](https://quran.com/6:139/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:139]]\n', 'queries': {'خلص بطن ذكر': '\n\n', 'شَرِيك': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.6:139](https://quran.com/6:139/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:139]]\n', 'queries': {'خلص بطن ذكر': '\n\n', 'شَرِيك': '\n\n', 'xlS bTn *kr (  )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.6:143](https://quran.com/6:143/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:143]]\n', 'queries': {'حرم انث': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.6:143](https://quran.com/6:143/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#6:143]]\n', 'queries': {'حرم انث': '\n\n', 'Hrm Anv ( )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.37:7](https://quran.com/37:7/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#37:7]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n', 'مرد (rebellious)': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.37:7](https://quran.com/37:7/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#37:7]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n', 'مرد (rebellious)': '\n\n', 'mrd (rebellious)': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.37:36](https://quran.com/37:36/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#37:36]]\n', 'queries': {'شعر ([Pp]oet(?!r))': '\n\n', 'جنن ((?:^mad$|mad man|madman|surely mad))': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.37:36](https://quran.com/37:36/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#37:36]]\n', 'queries': {'شعر ([Pp]oet(?!r))': '\n\n', 'جنن ((?:^mad$|mad man|madman|surely mad))': '\n\n', '$Er ([Pp]oet(?!r))': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.37:88](https://quran.com/37:88/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#37:88]]\n', 'queries': {'نجم نظر': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.37:88](https://quran.com/37:88/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#37:88]]\n', 'queries': {'نجم نظر': '\n\n', 'njm nZr ( )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.37:125](https://quran.com/37:125/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#37:123]]\n![[Qrsd#37:125]]', 'queries': {'بَعْل2 بعل': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.37:125](https://quran.com/37:125/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#37:123]]\n![[Qrsd#37:125]]', 'queries': {'بَعْل2 بعل': '\n\n', 'baEol2 ()': '![[bbl.history.neviim#1_kings#c18#22]]'}}
#
# Verse string before reading: {'string': '\n\n[Q.37:152](https://quran.com/37:152/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#37:152]]\n', 'queries': {'ولد اله ((?:begot|beget) )': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.37:152](https://quran.com/37:152/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#37:152]]\n', 'queries': {'ولد اله ((?:begot|beget) )': '\n\n', 'wld Alh ((?:begot|beget) )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.34:41](https://quran.com/34:41/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#34:41]]\n', 'queries': {'جِنّ ((?:[jJ]inn))': '\n\n', 'جنن دون عبد ((?:jinn)  )': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.34:41](https://quran.com/34:41/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#34:41]]\n', 'queries': {'جِنّ ((?:[jJ]inn))': '\n\n', 'جنن دون عبد ((?:jinn)  )': '\n\n', 'jnn dwn Ebd ((?:jinn)  )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.39:17](https://quran.com/39:17/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#39:17]]\n', 'queries': {'طَّٰغُوت طغي': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.39:17](https://quran.com/39:17/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#39:17]]\n', 'queries': {'طَّٰغُوت طغي': '\n\n', 'TaAguwt ()': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.41:37](https://quran.com/41:37/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#41:37]]\n', 'queries': {'شمس سجد لَا عبد': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.41:37](https://quran.com/41:37/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#41:37]]\n', 'queries': {'شمس سجد لَا عبد': '\n\n', '$ms sjd laA Ebd (   )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.42:21](https://quran.com/42:21/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#42:21]]\n', 'queries': {'شَرِيك': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.42:21](https://quran.com/42:21/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#42:21]]\n', 'queries': {'شَرِيك': '\n\n', 'jzA Ebd ( )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.43:16](https://quran.com/43:16/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#43:16]]\n', 'queries': {'اخذ بني ( (?:[Dd]aughter))': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.43:16](https://quran.com/43:16/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#43:16]]\n', 'queries': {'اخذ بني ( (?:[Dd]aughter))': '\n\n', 'Ax* bny ( (?:[Dd]aughter))': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.43:36](https://quran.com/43:36/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#43:36]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n', 'قرن (companion)': '\n\n', 'شطن قرن': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.43:36](https://quran.com/43:36/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#43:36]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n', 'قرن (companion)': '\n\n', 'شطن قرن': '\n\n', '$Tn qrn ( )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.43:77](https://quran.com/43:77/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#43:74]]![[Qrsd#43:77]]\n', 'queries': {'مَٰلِك2 ملك (malik )': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.43:77](https://quran.com/43:77/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#43:74]]![[Qrsd#43:77]]\n', 'queries': {'مَٰلِك2 ملك (malik )': '\n\n', 'maAlik (malik)': '![[bbl.prophecy.neviim#jeremiah#c32#35]]\n\n![[bbl.history.neviim#2_kings#c23#10]]\n'}}
#
# Verse string before reading: {'string': '\n\n[Q.16:57](https://quran.com/16:57/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#16:57]]\n', 'queries': {'جعل بني (assign (?:[Dd]aughter))': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.16:57](https://quran.com/16:57/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#16:57]]\n', 'queries': {'جعل بني (assign (?:[Dd]aughter))': '\n\n', 'jEl bny (assign (?:[Dd]aughter))': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.71:23](https://quran.com/71:23/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#71:21]]![[Qrsd#71:23]]\n', 'queries': {'وَدّ ودد (wadd )': '\n\n', 'سُوَاع سوع': '\n\n', 'نَسْر': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.71:23](https://quran.com/71:23/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#71:21]]![[Qrsd#71:23]]\n', 'queries': {'وَدّ ودد (wadd )': '\n\n', 'سُوَاع سوع': '\n\n', 'نَسْر': '\n\n', 'suwaAE ()': 'at ruḥāt yanbu\nby B hudhayl B mudrika B ilyas B Adnan'}}
#
# Verse string before reading: {'string': '\n\n[Q.70:43](https://quran.com/70:43/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#70:43]]\n', 'queries': {'نُصُب نُصْب': '\n\n', 'نُصُب نَصَب': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.70:43](https://quran.com/70:43/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#70:43]]\n', 'queries': {'نُصُب نُصْب': '\n\n', 'نُصُب نَصَب': '\n\n', 'nSb ((?:altar|goal))': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.29:17](https://quran.com/29:17/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#29:17]]\n', 'queries': {'وثن (idol)': '\n\n', 'عبد دون ((?:worship|serv) (?:other|esides|exclud|Us|instead))': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.29:17](https://quran.com/29:17/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#29:17]]\n', 'queries': {'وثن (idol)': '\n\n', 'عبد دون ((?:worship|serv) (?:other|esides|exclud|Us|instead))': '\n\n', 'wvn (idol)': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.3:80](https://quran.com/3:80/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#3:80]]\n', 'queries': {'ملك اخذ ربب ((?:[Aa]ngel)  (?:[Ll]ords))': '\n\n', 'نبا اخذ ربب (  (?:[Ll]ords))': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.3:80](https://quran.com/3:80/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#3:80]]\n', 'queries': {'ملك اخذ ربب ((?:[Aa]ngel)  (?:[Ll]ords))': '\n\n', 'نبا اخذ ربب (  (?:[Ll]ords))': '\n\n', 'mlk (viii)%20root%3AAx* rbb ((?:[Aa]ngel)  (?:[Ll]ords))': '## nbA (viii)%20root%3AAx* rbb (  (?:[Ll]ords))'}}
#
# Verse string before reading: {'string': '\n\n[Q.4:117](https://quran.com/4:117/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#4:117]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n', 'مرد (rebellious)': '\n\n', 'شطن انث دعو': '\n\n', 'دعو دون ((?:^((?!caller).)*$) (?:other|esides|exclud|Us|instead))': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.4:117](https://quran.com/4:117/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#4:117]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n', 'مرد (rebellious)': '\n\n', 'شطن انث دعو': '\n\n', 'دعو دون ((?:^((?!caller).)*$) (?:other|esides|exclud|Us|instead))': '\n\n', '$Tn Anv dEw (  )': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.5:90](https://quran.com/5:90/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#5:90]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.5:90](https://quran.com/5:90/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#5:90]]\n', 'queries': {'شطن ((?:devil|[^d]evil|demon|shaitaan))': '\n\n', 'zlm ()': ''}}
#
# Verse string before reading: {'string': '\n\n[Q.5:103](https://quran.com/5:103/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#5:103]]\n', 'queries': {'سَآئِبَة': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.5:103](https://quran.com/5:103/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#5:103]]\n', 'queries': {'سَآئِبَة': '\n\n', 'syb ()': '## wSl (Wasilah)'}}
#
# Verse string before reading: {'string': '\n\n[Q.9:31](https://quran.com/9:31/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#9:31]]\n', 'queries': {'عبد دون ((?:worship|serv) (?:other|esides|exclud|Us|instead))': '\n\n', 'اخذ اله ( (?:^((?!Allah).)*$))': '\n\n', 'اخذ دون': '\n\n', 'رهب ربب اخذ (  (?:taken))': '\n\n', 'حبر ربب اخذ (  (?:taken))': '\n\n'}}
#
# Verse string after reading: {'string': '\n\n[Q.9:31](https://quran.com/9:31/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsd#9:31]]\n', 'queries': {'عبد دون ((?:worship|serv) (?:other|esides|exclud|Us|instead))': '\n\n', 'اخذ اله ( (?:^((?!Allah).)*$))': '\n\n', 'اخذ دون': '\n\n', 'رهب ربب اخذ (  (?:taken))': '\n\n', 'حبر ربب اخذ (  (?:taken))': '\n\n', 'Hbr rbb Ax* (  (?:taken))': '## rhb rbb Ax* (  (?:taken))'}}
#
# Number of ayahs: 332

# %%
flnm = "shrk"
mdFile = f'data/compare/{flnm}.md'
import os

if os.path.isfile(mdFile):
    import re

    with open(mdFile) as f:
        strn = f.read()

    olds = re.compile(
            '\n#\s*'
            +'(?:Q\:){0,1}'
            +'(\d{1,}\:\d{1,})'
            +'(.*?(?=\n#|$))'
            # +'(?:'
            +'(\n##\s{1,}.'
            +'*?'
            +'(?=\n#\s{1,}|$)'
            # +')'
            +'){0,1}'
            ,
            re.DOTALL
        ).findall(

        strn
    )

olds
# Out:
# [('7:33',
#   '\n[Q.7:33](https://quran.com/7:33/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#7:33]]\n',
#   '\n## شرك iv\n\n'),
#  ('7:173',
#   '\n[Q.7:173](https://quran.com/7:173/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#7:173]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('7:190',
#   '\n[Q.7:190](https://quran.com/7:190/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#7:190]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('7:191',
#   '\n[Q.7:191](https://quran.com/7:191/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#7:191]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('72:2',
#   '\n[Q.72:2](https://quran.com/72:2/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#72:2]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('72:20',
#   '\n[Q.72:20](https://quran.com/72:20/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#72:20]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('35:14',
#   '\n[Q.35:14](https://quran.com/35:14/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#35:14]]\n',
#   '\n## شِرْك\n\n'),
#  ('35:40',
#   '\n[Q.35:40](https://quran.com/35:40/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#35:40]]\n',
#   '\n## ~~~ شِرْك\n1st inst: [[#Q:35:14]]\n\n'),
#  ('20:32',
#   '\n[Q.20:32](https://quran.com/20:32/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#20:32]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('27:59',
#   '\n[Q.27:59](https://quran.com/27:59/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#27:59]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('27:63',
#   '\n[Q.27:63](https://quran.com/27:63/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#27:63]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('28:68',
#   '\n[Q.28:68](https://quran.com/28:68/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#28:68]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('28:87',
#   '\n[Q.28:87](https://quran.com/28:87/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#28:87]]\n',
#   '\n## مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n\n'),
#  ('17:64',
#   '\n[Q.17:64](https://quran.com/17:64/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#17:64]]\n',
#   '\n## شرك iii\n\n'),
#  ('10:18',
#   '\n[Q.10:18](https://quran.com/10:18/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#10:18]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('10:28',
#   '\n[Q.10:28](https://quran.com/10:28/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#10:28]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('10:105',
#   '\n[Q.10:105](https://quran.com/10:105/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#10:105]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('11:54',
#   '\n[Q.11:54](https://quran.com/11:54/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#11:54]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('12:38',
#   '\n[Q.12:38](https://quran.com/12:38/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#12:38]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('12:106',
#   '\n[Q.12:106](https://quran.com/12:106/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#12:106]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('12:108',
#   '\n[Q.12:108](https://quran.com/12:108/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#12:108]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('15:94',
#   '\n[Q.15:94](https://quran.com/15:94/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#15:94]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('6:14',
#   '\n[Q.6:14](https://quran.com/6:14/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:14]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('6:19',
#   '\n[Q.6:19](https://quran.com/6:19/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:19]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('6:22',
#   '\n[Q.6:22](https://quran.com/6:22/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:22]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('6:41',
#   '\n[Q.6:41](https://quran.com/6:41/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:41]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('6:64',
#   '\n[Q.6:64](https://quran.com/6:64/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:64]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('6:78',
#   '\n[Q.6:78](https://quran.com/6:78/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:78]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('6:79',
#   '\n[Q.6:79](https://quran.com/6:79/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:79]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('6:80',
#   '\n[Q.6:80](https://quran.com/6:80/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:80]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('6:81',
#   '\n[Q.6:81](https://quran.com/6:81/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:81]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('6:88',
#   '\n[Q.6:88](https://quran.com/6:88/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:88]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('6:106',
#   '\n[Q.6:106](https://quran.com/6:106/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:106]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('6:107',
#   '\n[Q.6:107](https://quran.com/6:107/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:107]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('6:121',
#   '\n[Q.6:121](https://quran.com/6:121/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:121]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('6:137',
#   '\n[Q.6:137](https://quran.com/6:137/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:137]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('6:148',
#   '\n[Q.6:148](https://quran.com/6:148/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:148]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('6:161',
#   '\n[Q.6:161](https://quran.com/6:161/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:161]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('37:33',
#   '\n[Q.37:33](https://quran.com/37:33/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#37:33]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('31:13',
#   '\n[Q.31:13](https://quran.com/31:13/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#31:13]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n\n## ~~~ شِرْك\n1st inst: [[#Q:35:14]]\n\n'),
#  ('31:15',
#   '\n[Q.31:15](https://quran.com/31:15/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#31:15]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('34:22',
#   '\n[Q.34:22](https://quran.com/34:22/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#34:22]]\n',
#   '\n## ~~~ شِرْك\n1st inst: [[#Q:35:14]]\n\n'),
#  ('39:65',
#   '\n[Q.39:65](https://quran.com/39:65/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#39:65]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('39:67',
#   '\n[Q.39:67](https://quran.com/39:67/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#39:67]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('40:12',
#   '\n[Q.40:12](https://quran.com/40:12/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#40:12]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('40:42',
#   '\n[Q.40:42](https://quran.com/40:42/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#40:42]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('40:73',
#   '\n[Q.40:73](https://quran.com/40:73/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#40:73]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('40:84',
#   '\n[Q.40:84](https://quran.com/40:84/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#40:84]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('41:6',
#   '\n[Q.41:6](https://quran.com/41:6/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#41:6]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('42:13',
#   '\n[Q.42:13](https://quran.com/42:13/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#42:13]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('43:39',
#   '\n[Q.43:39](https://quran.com/43:39/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#43:39]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('46:4',
#   '\n[Q.46:4](https://quran.com/46:4/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#46:4]]\n',
#   '\n## ~~~ شِرْك\n1st inst: [[#Q:35:14]]\n\n'),
#  ('18:26',
#   '\n[Q.18:26](https://quran.com/18:26/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#18:26]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('18:38',
#   '\n[Q.18:38](https://quran.com/18:38/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#18:38]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('18:42',
#   '\n[Q.18:42](https://quran.com/18:42/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#18:42]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('18:110',
#   '\n[Q.18:110](https://quran.com/18:110/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#18:110]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('16:1',
#   '\n[Q.16:1](https://quran.com/16:1/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#16:1]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('16:3',
#   '\n[Q.16:3](https://quran.com/16:3/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#16:3]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('16:35',
#   '\n[Q.16:35](https://quran.com/16:35/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#16:35]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('16:54',
#   '\n[Q.16:54](https://quran.com/16:54/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#16:54]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('16:86',
#   '\n[Q.16:86](https://quran.com/16:86/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#16:86]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('16:100',
#   '\n[Q.16:100](https://quran.com/16:100/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#16:100]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('16:120',
#   '\n[Q.16:120](https://quran.com/16:120/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#16:120]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('16:123',
#   '\n[Q.16:123](https://quran.com/16:123/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#16:123]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('14:22',
#   '\n[Q.14:22](https://quran.com/14:22/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#14:22]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('23:59',
#   '\n[Q.23:59](https://quran.com/23:59/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#23:59]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('23:92',
#   '\n[Q.23:92](https://quran.com/23:92/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#23:92]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('52:43',
#   '\n[Q.52:43](https://quran.com/52:43/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#52:43]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('30:31',
#   '\n[Q.30:31](https://quran.com/30:31/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#30:31]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('30:33',
#   '\n[Q.30:33](https://quran.com/30:33/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#30:33]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('30:35',
#   '\n[Q.30:35](https://quran.com/30:35/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#30:35]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('30:40',
#   '\n[Q.30:40](https://quran.com/30:40/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#30:40]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('30:42',
#   '\n[Q.30:42](https://quran.com/30:42/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#30:42]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('29:65',
#   '\n[Q.29:65](https://quran.com/29:65/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#29:65]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('6:23',
#   '\n[Q.6:23](https://quran.com/6:23/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:23]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('6:151',
#   '\n[Q.6:151](https://quran.com/6:151/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#6:151]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('29:8',
#   '\n[Q.29:8](https://quran.com/29:8/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#29:8]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('2:96',
#   '\n[Q.2:96](https://quran.com/2:96/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#2:96]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('2:105',
#   '\n[Q.2:105](https://quran.com/2:105/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#2:105]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('2:135',
#   '\n[Q.2:135](https://quran.com/2:135/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#2:135]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('2:221',
#   '\n[Q.2:221](https://quran.com/2:221/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#2:221]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('3:64',
#   '\n[Q.3:64](https://quran.com/3:64/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#3:64]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('3:67',
#   '\n[Q.3:67](https://quran.com/3:67/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#3:67]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('3:95',
#   '\n[Q.3:95](https://quran.com/3:95/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#3:95]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('3:151',
#   '\n[Q.3:151](https://quran.com/3:151/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#3:151]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('3:186',
#   '\n[Q.3:186](https://quran.com/3:186/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#3:186]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('33:73',
#   '\n[Q.33:73](https://quran.com/33:73/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#33:73]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('60:12',
#   '\n[Q.60:12](https://quran.com/60:12/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#60:12]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('4:36',
#   '\n[Q.4:36](https://quran.com/4:36/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#4:36]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('4:48',
#   '\n[Q.4:48](https://quran.com/4:48/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#4:48]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('4:116',
#   '\n[Q.4:116](https://quran.com/4:116/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#4:116]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('13:36',
#   '\n[Q.13:36](https://quran.com/13:36/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#13:36]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('98:1',
#   '\n[Q.98:1](https://quran.com/98:1/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#98:1]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('98:6',
#   '\n[Q.98:6](https://quran.com/98:6/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#98:6]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('59:23',
#   '\n[Q.59:23](https://quran.com/59:23/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#59:23]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('24:3',
#   '\n[Q.24:3](https://quran.com/24:3/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#24:3]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('24:55',
#   '\n[Q.24:55](https://quran.com/24:55/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#24:55]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('22:17',
#   '\n[Q.22:17](https://quran.com/22:17/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#22:17]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('22:26',
#   '\n[Q.22:26](https://quran.com/22:26/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#22:26]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('22:31',
#   '\n[Q.22:31](https://quran.com/22:31/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#22:31]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('61:9',
#   '\n[Q.61:9](https://quran.com/61:9/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#61:9]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('48:6',
#   '\n[Q.48:6](https://quran.com/48:6/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#48:6]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('5:72',
#   '\n[Q.5:72](https://quran.com/5:72/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#5:72]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('5:82',
#   '\n[Q.5:82](https://quran.com/5:82/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#5:82]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('9:1',
#   '\n[Q.9:1](https://quran.com/9:1/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:1]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('9:3',
#   '\n[Q.9:3](https://quran.com/9:3/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:3]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('9:4',
#   '\n[Q.9:4](https://quran.com/9:4/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:4]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('9:5',
#   '\n[Q.9:5](https://quran.com/9:5/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:5]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('9:6',
#   '\n[Q.9:6](https://quran.com/9:6/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:6]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('9:7',
#   '\n[Q.9:7](https://quran.com/9:7/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:7]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('9:17',
#   '\n[Q.9:17](https://quran.com/9:17/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:17]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('9:28',
#   '\n[Q.9:28](https://quran.com/9:28/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:28]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('9:31',
#   '\n[Q.9:31](https://quran.com/9:31/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:31]]\n',
#   '\n## ~~~ شرك iv\n1st inst: [[#Q:7:33]]\n\n'),
#  ('9:33',
#   '\n[Q.9:33](https://quran.com/9:33/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:33]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('9:36',
#   '\n[Q.9:36](https://quran.com/9:36/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:36]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n\n'),
#  ('9:113',
#   '\n[Q.9:113](https://quran.com/9:113/tafsirs/ar-tafsir-al-tabari)\n\n![[Qrsi#9:113]]\n',
#   '\n## ~~~ مُشْرِك / مُشْرِكَٰت / مُشْرِكَة / مُشْتَرِكُون\n1st inst: [[#Q:28:87]]\n')]

# %%
queriesOld = olds[1][2]

secondaries = re.findall(
                '((?<=\n)##\s{1,}[^\n]*\n*)'
                +'((?:\n*1st inst\: \[\[[^\n]*\]\]\n*){0,1})'
                +'((?:(?!1st inst:|\n## ).)*?'
                # +'(^(?!1st inst\:)[^#]'
                # +'(.*'
                +'(?=\n## |$)*$'
                +')',
                queriesOld,
                re.DOTALL,
            )

print(queriesOld, '\n', secondaries)
# Out:
# ## ~~~ شرك iv
# 1st inst: [[#Q:7:33]]
#
#
#  [('## ~~~ شرك iv\n', '1st inst: [[#Q:7:33]]\n\n', '')]

# %%
from aggregates_test import *

from qChronoMd import qChronoMd

qChronoMd(
    [   
        *qwl_kfr,
        # *hwy,
        # *znn,
        # *zEm,
        # *fry,
        # *kdhb,
    ],
    flnm='qwl_kfr',
    # flnm='hwy_znn_zEm_fry_kdhb',
    refLng='arabic'
)
# Out:
# total 91 instances found
# 'sorter.json' found'
# last item in sorter: 110:3
# successfully loaded sorter of length 6236 from 'sorter.json'
#
# Number of ayahs: 91

# %%
import re

sK = "~~~ كَٰذِب 32"

sKSt = re.sub(
    '^(?:~~~ |)(.*?)\s*\d*$',
    '\\1',
    sK
)

sKSt
# Out:
# 'كَٰذِب'
